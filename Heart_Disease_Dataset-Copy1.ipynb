# %%
from bitarray import bitarray
import random
import numpy as np
import math

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %%
import pandas as pd
import os

# %%
file = pd.read_csv("heart.csv")
file.head()
file.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
X = np.array(file.values[:,:-1])
X = StandardScaler().fit_transform(X)
y = np.array(file.values[:,-1]).reshape(-1,1).astype(int)

# %%
y_pos=y[y==1]
y_neg=y[y==0]
x_neg=X[165:303]
x_pos=X[0:165]
np.random.shuffle(x_neg)
print(x_neg.shape)
print(x_pos.shape)
# Out:
# (138, 13)
# (165, 13)

# %%
indices=np.arange(69)
#x_train=np.array(x_neg[0:106])[indices]
y_train=y_neg[0:69]
x_train=np.concatenate((np.array(x_neg[0:69])[indices],x_pos)).reshape(-1,13)
y_train=np.concatenate((y_train,y_pos)).reshape(-1,1)

# %%
print(x_train.shape)
print(y_train.shape)
print(sum(y_train))
# Out:
# (234, 13)
# (234, 1)
# [165]

# %%
x_test = x_neg[69:138].reshape(-1,13)
y_test = y_neg[69:138].reshape(-1,1)

# %%
fpr_values_kraska = []
size_values_kraska = []

# %% [markdown]
# # Kraska Hash Model

# %%
class Kraska_Hash_BloomFilter:
    
    def __init__(self, size, model): #hash count is 1
        self.size = size
      #  self.hash_count = hash_count
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)
        self.model=model #classifier model associated as hash function
        
    def add(self, num):
        #for seed in range(1,self.hash_count+1):
            #result = mmh3.hash(str(num), seed) % self.size
        result=math.floor(model.predict(num)[0]*(self.size-1))    
        self.bit_array[result] = 1
            
    def lookup(self, num):
        #for seed in range(1,self.hash_count+1):
            #result = mmh3.hash(str(num), seed) % self.size
        result=math.floor(self.model.predict(num)[0]*(self.size-1))    
        if self.bit_array[result] == 0:
                return False
        return True

    def add_init(self,x_train,y_train):
        pred = self.model.predict(x_train)
        for i in range(len(pred)):
            if(y_train[i]==1):
                result = math.floor(pred[i][0]*(self.size-1))
                self.bit_array[result] = 1

    def predict(self,x):
        initpred = self.model.predict(x)
        indexes = []
        for i in range(len(initpred)):
            indexes += [math.floor(initpred[i][0]*(self.size-1))]
        pred = []
        for i in indexes:
            pred += [self.bit_array[i]]
        return np.array(pred)

#adds ratio r of an array of random integers of size n to bloom filter bf(input : bf,size,ratio; output: data array)
def addrandom(bf,n,r):
    data=np.empty(n,dtype=int)
    for i in range(0,n):
        data[i]=random.randint(0, 100000000)
    for j in range(0,int(n*r)):
        bf.add(data[j])
    return data

#(Input:bloom filter,number array,ratio of positives; Output:(-1) for false negative, otherwise fpr)
def fpr_kraska_hash(bf,x_test,y_test):
    pred = bf.predict(x_test)
    tn, fp, fn, tp = confusion_matrix(y_test,pred,labels=[False,True]).ravel() 
    return fp/(fp+tn)

#(Input:bloom filter size, total random numbers, ratio of number inserted; Output:efficient number of hash functions)
def eff_k(m,n,r):
    k=int(m/(int(n*r))*math.log(2))
    if(k==0):
        return 1
    return k

#(Input:size of bloom filter, number of hash functions, total numbers, ratio of numbers inserted; Output: fpr)
def find_fpr(m,model,n,r):
    bf=Kraska_Hash_BloomFilter(model,m)
    data=addrandom(bf,n,r)
    return fpr(bf,data,r)

#(Input:size of bloom filter, total numbers, ratio of numbers inserted; Output: prints inputs and fpr)
def outputs(m,n,r):
    find_fpr(m,model,n,r)
    #print("For m=%d, k=%d, n=%d, r=%.3f: fpr=%.3f"%(m,k,n,r,find_fpr(m,k,n,r)))

# %%
def get_data_points_Kraska(x_train,y_train,x_test,y_test,init_size,diff,num,epochs,fpr_values_kraska,size_values_kraska):
    batch_size = len(x_train)
    input_dim = x_train.shape[1]
    additional_metrics = ['acc']
    loss_function = BinaryCrossentropy()
    optimizer = Adam()
    verbosity_mode = 0
    for i in range(0,num):
        layer_size = init_size + (diff*i)
        number_of_epochs = epochs
        model = Sequential()
        model.add(Dense(layer_size,input_dim=input_dim,activation='relu'))
        model.add(Dense(1,activation='sigmoid'))
        model.compile(optimizer=optimizer, loss=loss_function, metrics=additional_metrics)
        history = model.fit(x_train, y_train, batch_size = batch_size, epochs=number_of_epochs, verbose=verbosity_mode)

        print("Number of nodes: %d" %(init_size + (diff*i)))
        plt.plot(history.history['acc'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.show()
        plt.plot(history.history['loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.show()

        model_size = ((input_dim+1)*layer_size + (layer_size+1))*32

        m = int(model_size/10) + 1
        net_size = model_size + m

        bf=Kraska_Hash_BloomFilter(m,model)
        bf.add_init(x_train,y_train)
        fpr = fpr_kraska_hash(bf,x_test,y_test)

        print("Size: %f bits - FPR: %f \n\n\n" % (net_size,fpr))
        fpr_values_kraska += [fpr]
        size_values_kraska += [net_size]

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# WARNING:tensorflow:From /Users/aditijain/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/aditijain/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Number of nodes: 1
# Size: 1025.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 2
# Size: 1985.000000 bits - FPR: 0.342995
#
#
#
# Number of nodes: 3
# Size: 2945.000000 bits - FPR: 0.357488
#
#
#
# Number of nodes: 4
# Size: 3905.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 5
# Size: 4865.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 6
# Size: 5825.000000 bits - FPR: 0.193237
#
#
#
# Number of nodes: 7
# Size: 6785.000000 bits - FPR: 0.256039
#
#
#
# Number of nodes: 8
# Size: 7745.000000 bits - FPR: 0.251208
#
#
#
# Number of nodes: 9
# Size: 8705.000000 bits - FPR: 0.231884
#
#
#
# Number of nodes: 10
# Size: 9665.000000 bits - FPR: 0.231884
#
#
#
# Number of nodes: 11
# Size: 10625.000000 bits - FPR: 0.246377
#
#
#
# Number of nodes: 12
# Size: 11585.000000 bits - FPR: 0.236715
#
#
#
# Number of nodes: 13
# Size: 12545.000000 bits - FPR: 0.202899
#
#
#
# Number of nodes: 14
# Size: 13505.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 15
# Size: 14465.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 16
# Size: 15425.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 17
# Size: 16385.000000 bits - FPR: 0.236715
#
#
#
# Number of nodes: 18
# Size: 17345.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 19
# Size: 18305.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 20
# Size: 19265.000000 bits - FPR: 0.202899

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# Number of nodes: 1
# Size: 1025.000000 bits - FPR: 0.690821
#
#
#
# Number of nodes: 2
# Size: 1985.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 3
# Size: 2945.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 4
# Size: 3905.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 5
# Size: 4865.000000 bits - FPR: 0.207729
#
#
#
# Number of nodes: 6
# Size: 5825.000000 bits - FPR: 0.246377
#
#
#
# Number of nodes: 7
# Size: 6785.000000 bits - FPR: 0.159420
#
#
#
# Number of nodes: 8
# Size: 7745.000000 bits - FPR: 0.202899
#
#
#
# Number of nodes: 9
# Size: 8705.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 10
# Size: 9665.000000 bits - FPR: 0.193237
#
#
#
# Number of nodes: 11
# Size: 10625.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 12
# Size: 11585.000000 bits - FPR: 0.188406
#
#
#
# Number of nodes: 13
# Size: 12545.000000 bits - FPR: 0.198068
#
#
#
# Number of nodes: 14
# Size: 13505.000000 bits - FPR: 0.256039
#
#
#
# Number of nodes: 15
# Size: 14465.000000 bits - FPR: 0.198068
#
#
#
# Number of nodes: 16
# Size: 15425.000000 bits - FPR: 0.231884
#
#
#
# Number of nodes: 17
# Size: 16385.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 18
# Size: 17345.000000 bits - FPR: 0.212560
#
#
#
# Number of nodes: 19
# Size: 18305.000000 bits - FPR: 0.207729
#
#
#
# Number of nodes: 20
# Size: 19265.000000 bits - FPR: 0.178744

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# Number of nodes: 1
# Size: 1025.000000 bits - FPR: 0.574879
#
#
#
# Number of nodes: 2
# Size: 1985.000000 bits - FPR: 0.231884
#
#
#
# Number of nodes: 3
# Size: 2945.000000 bits - FPR: 0.193237
#
#
#
# Number of nodes: 4
# Size: 3905.000000 bits - FPR: 0.294686
#
#
#
# Number of nodes: 5
# Size: 4865.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 6
# Size: 5825.000000 bits - FPR: 0.207729
#
#
#
# Number of nodes: 7
# Size: 6785.000000 bits - FPR: 0.236715
#
#
#
# Number of nodes: 8
# Size: 7745.000000 bits - FPR: 0.212560
#
#
#
# Number of nodes: 9
# Size: 8705.000000 bits - FPR: 0.217391
#
#
#
# Number of nodes: 10
# Size: 9665.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 11
# Size: 10625.000000 bits - FPR: 0.236715
#
#
#
# Number of nodes: 12
# Size: 11585.000000 bits - FPR: 0.222222
#
#
#
# Number of nodes: 13
# Size: 12545.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 14
# Size: 13505.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 15
# Size: 14465.000000 bits - FPR: 0.198068
#
#
#
# Number of nodes: 16
# Size: 15425.000000 bits - FPR: 0.202899
#
#
#
# Number of nodes: 17
# Size: 16385.000000 bits - FPR: 0.212560
#
#
#
# Number of nodes: 18
# Size: 17345.000000 bits - FPR: 0.227053
#
#
#
# Number of nodes: 19
# Size: 18305.000000 bits - FPR: 0.241546
#
#
#
# Number of nodes: 20
# Size: 19265.000000 bits - FPR: 0.212560

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=fpr_values_kraska, err_style="band",label = "Kraska",linewidth = 1.5,marker="o")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %% [markdown]
# # Projection model

# %%
class Projection_BloomFilter:
    def __init__(self, size, hash_count, dim):
        vectors = np.random.normal(0,1,size=(hash_count,dim)) #random vectors(each row) from normal distribution, not unit vectors
        i=0
        #while(i<hash_count):
            #if(vectors[i][0]<0):
                #vectors[i][0] *= -1
               # print("initial v", vectors[i])
                #vectors[i]=np.random.normal(0,1,size=(1,dim))
                #print("changed v", vectors[i])
            #i = i+1
       # print(vectors)        
        self.unit_vectors = np.transpose(vectors/np.sqrt(np.transpose([np.sum(np.multiply(vectors,vectors),1)]))) #Matrix where each column is a unit vector, used as hash
        #self.unit_vectors = np.transpose(vectors)
        self.size = size
        self.hash_count = hash_count
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)

    def give_hash_values(self,X):
        projections = np.dot(X,self.unit_vectors) #Projections of datapoints on unit vectors
        norm_proj = 1/(1+np.exp(-projections)) #Sigmoid on each value so that they are in the range (0,1)
        hash_values = (norm_proj*(self.size-1)).astype(int) #All values are integers in the range [0,size-1]
        return hash_values                        #Each row contains hash values of that datapoint

    def add(self,x):
        hash_values = self.give_hash_values(x)
        for i in hash_values:
            self.bit_array[i] = 1
        
    def bulk_add(self, X):
        hash_values = self.give_hash_values(X)
        for i in hash_values:
            for j in i:
                self.bit_array[j] = 1
            
    def lookup(self, x):
        hash_values = self.give_hash_values(x)
        for i in hash_values:
            if(self.bit_array[i]==0):
                return False
        return True
   
#(Input:bloom filter,normalized positive data,normalized negative data; Output:(-1) for false negative, otherwise fpr)
def find_fpr(bf,x_pos,x_neg):
    fp = 0
    tn = 0
    pos_hash_values = bf.give_hash_values(x_pos)
    neg_hash_values = bf.give_hash_values(x_neg)
    for i in pos_hash_values:
        for j in i:
            if(bf.bit_array[j]==0):
                return -1
    for i in neg_hash_values:
        flag = 0
        for j in i:
            if(bf.bit_array[j]==0):
                tn += 1 
                flag = 1           
                break
        if(flag==0):
            fp += 1
    return fp/(fp+tn)

def find_fpr2(bf,x_neg):
    fp = 0
    tn = 0
    neg_hash_values = bf.give_hash_values(x_neg)
    for i in neg_hash_values:
        flag = 0
        for j in i:
            if(bf.bit_array[j]==0):
                tn += 1 
                flag = 1           
                break
        if(flag==0):
            fp += 1
    return fp/(fp+tn)
 
def eff_k(m,n,r):
    k=int(m/(int(n*r))*math.log(2))
    if(k==0):
        return 1
    return k

# %%
def get_data_points_Projection(x_train,x_test,y_train,init_size,diff,num,epochs,fpr_values,size_values):
    input_dim = x_train.shape[1]
    n = sum(y_train)
    x_pos = x_train[(y_train==1).reshape(-1)]
    print(x_pos.shape)
    x_neg = x_train[(y_train==0).reshape(-1)]
    for i in range(0,num):
        m = init_size + i*diff
        k = eff_k(m,n,1)
        fpr = 1
        tempbf = Projection_BloomFilter(m,k,input_dim)
        for j in range(0,epochs):
            bf = Projection_BloomFilter(m,k,input_dim)
            bf.bulk_add(x_pos)
            temp = find_fpr(bf,x_pos,x_neg)
            if(fpr>temp):
                fpr = temp
                tempbf=bf
        fpr_test=find_fpr2(tempbf,x_test)
        print("Size: %d Bits - FPR: %f \n\n\n" % (m,fpr_test))
        fpr_values += [fpr_test]
        size_values += [m]

# %%
fpr_values = []
size_values = []

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (165, 13)
# Size: 5 Bits - FPR: 0.000000
#
#
#
# Size: 15 Bits - FPR: 0.814493
#
#
#
# Size: 25 Bits - FPR: 0.805797
#
#
#
# Size: 35 Bits - FPR: 0.802899
#
#
#
# Size: 45 Bits - FPR: 0.652174
#
#
#
# Size: 55 Bits - FPR: 0.739130
#
#
#
# Size: 65 Bits - FPR: 0.669565
#
#
#
# Size: 75 Bits - FPR: 0.579710
#
#
#
# Size: 85 Bits - FPR: 0.492754
#
#
#
# Size: 95 Bits - FPR: 0.466667
#
#
#
# Size: 105 Bits - FPR: 0.579710
#
#
#
# Size: 115 Bits - FPR: 0.484058
#
#
#
# Size: 125 Bits - FPR: 0.556522
#
#
#
# Size: 135 Bits - FPR: 0.571014
#
#
#
# Size: 145 Bits - FPR: 0.518841
#
#
#
# Size: 155 Bits - FPR: 0.492754
#
#
#
# Size: 165 Bits - FPR: 0.417391
#
#
#
# Size: 175 Bits - FPR: 0.391304
#
#
#
# Size: 185 Bits - FPR: 0.492754
#
#
#
# Size: 195 Bits - FPR: 0.353623
#
#
#
# Size: 205 Bits - FPR: 0.411594
#
#
#
# Size: 215 Bits - FPR: 0.376812
#
#
#
# Size: 225 Bits - FPR: 0.460870
#
#
#
# Size: 235 Bits - FPR: 0.263768
#
#
#
# Size: 245 Bits - FPR: 0.457971
#
#
#
# Size: 255 Bits - FPR: 0.333333
#
#
#
# Size: 265 Bits - FPR: 0.307246
#
#
#
# Size: 275 Bits - FPR: 0.379710
#
#
#
# Size: 285 Bits - FPR: 0.333333
#
#
#
# Size: 295 Bits - FPR: 0.391304
#
#
#
# Size: 305 Bits - FPR: 0.362319
#
#
#
# Size: 315 Bits - FPR: 0.452174
#
#
#
# Size: 325 Bits - FPR: 0.292754
#
#
#
# Size: 335 Bits - FPR: 0.208696
#
#
#
# Size: 345 Bits - FPR: 0.228986
#
#
#
# Size: 355 Bits - FPR: 0.231884
#
#
#
# Size: 365 Bits - FPR: 0.353623
#
#
#
# Size: 375 Bits - FPR: 0.205797
#
#
#
# Size: 385 Bits - FPR: 0.220290
#
#
#
# Size: 395 Bits - FPR: 0.257971
#
#
#
# Size: 405 Bits - FPR: 0.173913
#
#
#
# Size: 415 Bits - FPR: 0.255072
#
#
#
# Size: 425 Bits - FPR: 0.200000
#
#
#
# Size: 435 Bits - FPR: 0.281159
#
#
#
# Size: 445 Bits - FPR: 0.188406
#
#
#
# Size: 455 Bits - FPR: 0.237681
#
#
#
# Size: 465 Bits - FPR: 0.173913
#
#
#
# Size: 475 Bits - FPR: 0.115942
#
#
#
# Size: 485 Bits - FPR: 0.231884
#
#
#
# Size: 495 Bits - FPR: 0.127536
#
#
#
# Size: 505 Bits - FPR: 0.162319
#
#
#
# Size: 515 Bits - FPR: 0.246377
#
#
#
# Size: 525 Bits - FPR: 0.173913
#
#
#
# Size: 535 Bits - FPR: 0.194203
#
#
#
# Size: 545 Bits - FPR: 0.275362
#
#
#
# Size: 555 Bits - FPR: 0.168116
#
#
#
# Size: 565 Bits - FPR: 0.237681
#
#
#
# Size: 575 Bits - FPR: 0.147826
#
#
#
# Size: 585 Bits - FPR: 0.231884
#
#
#
# Size: 595 Bits - FPR: 0.153623
#
#
#
# Size: 605 Bits - FPR: 0.159420
#
#
#
# Size: 615 Bits - FPR: 0.130435
#
#
#
# Size: 625 Bits - FPR: 0.130435
#
#
#
# Size: 635 Bits - FPR: 0.182609
#
#
#
# Size: 645 Bits - FPR: 0.179710
#
#
#
# Size: 655 Bits - FPR: 0.127536
#
#
#
# Size: 665 Bits - FPR: 0.153623
#
#
#
# Size: 675 Bits - FPR: 0.162319
#
#
#
# Size: 685 Bits - FPR: 0.173913
#
#
#
# Size: 695 Bits - FPR: 0.130435
#
#
#
# Size: 705 Bits - FPR: 0.159420
#
#
#
# Size: 715 Bits - FPR: 0.159420
#
#
#
# Size: 725 Bits - FPR: 0.139130
#
#
#
# Size: 735 Bits - FPR: 0.101449
#
#
#
# Size: 745 Bits - FPR: 0.115942
#
#
#
# Size: 755 Bits - FPR: 0.136232
#
#
#
# Size: 765 Bits - FPR: 0.171014
#
#
#
# Size: 775 Bits - FPR: 0.098551
#
#
#
# Size: 785 Bits - FPR: 0.127536
#
#
#
# Size: 795 Bits - FPR: 0.101449
#
#
#
# Size: 805 Bits - FPR: 0.142029
#
#
#
# Size: 815 Bits - FPR: 0.092754
#
#
#
# Size: 825 Bits - FPR: 0.110145
#
#
#
# Size: 835 Bits - FPR: 0.144928
#
#
#
# Size: 845 Bits - FPR: 0.101449
#
#
#
# Size: 855 Bits - FPR: 0.037681
#
#
#
# Size: 865 Bits - FPR: 0.162319
#
#
#
# Size: 875 Bits - FPR: 0.110145
#
#
#
# Size: 885 Bits - FPR: 0.075362
#
#
#
# Size: 895 Bits - FPR: 0.159420
#
#
#
# Size: 905 Bits - FPR: 0.162319
#
#
#
# Size: 915 Bits - FPR: 0.066667
#
#
#
# Size: 925 Bits - FPR: 0.113043
#
#
#
# Size: 935 Bits - FPR: 0.159420
#
#
#
# Size: 945 Bits - FPR: 0.130435
#
#
#
# Size: 955 Bits - FPR: 0.057971
#
#
#
# Size: 965 Bits - FPR: 0.136232
#
#
#
# Size: 975 Bits - FPR: 0.092754
#
#
#
# Size: 985 Bits - FPR: 0.086957
#
#
#
# Size: 995 Bits - FPR: 0.043478
#
#
#
# Size: 1005 Bits - FPR: 0.043478
#
#
#
# Size: 1015 Bits - FPR: 0.084058
#
#
#
# Size: 1025 Bits - FPR: 0.075362
#
#
#
# Size: 1035 Bits - FPR: 0.072464
#
#
#
# Size: 1045 Bits - FPR: 0.034783
#
#
#
# Size: 1055 Bits - FPR: 0.084058
#
#
#
# Size: 1065 Bits - FPR: 0.104348
#
#
#
# Size: 1075 Bits - FPR: 0.060870
#
#
#
# Size: 1085 Bits - FPR: 0.028986
#
#
#
# Size: 1095 Bits - FPR: 0.028986
#
#
#
# Size: 1105 Bits - FPR: 0.023188
#
#
#
# Size: 1115 Bits - FPR: 0.057971
#
#
#
# Size: 1125 Bits - FPR: 0.086957
#
#
#
# Size: 1135 Bits - FPR: 0.072464
#
#
#
# Size: 1145 Bits - FPR: 0.028986
#
#
#
# Size: 1155 Bits - FPR: 0.028986
#
#
#
# Size: 1165 Bits - FPR: 0.057971
#
#
#
# Size: 1175 Bits - FPR: 0.130435
#
#
#
# Size: 1185 Bits - FPR: 0.101449
#
#
#
# Size: 1195 Bits - FPR: 0.014493
#
#
#
# Size: 1205 Bits - FPR: 0.014493
#
#
#
# Size: 1215 Bits - FPR: 0.043478
#
#
#
# Size: 1225 Bits - FPR: 0.072464
#
#
#
# Size: 1235 Bits - FPR: 0.057971
#
#
#
# Size: 1245 Bits - FPR: 0.043478
#
#
#
# Size: 1255 Bits - FPR: 0.014493
#
#
#
# Size: 1265 Bits - FPR: 0.086957
#
#
#
# Size: 1275 Bits - FPR: 0.130435
#
#
#
# Size: 1285 Bits - FPR: 0.028986
#
#
#
# Size: 1295 Bits - FPR: 0.028986
#
#
#
# Size: 1305 Bits - FPR: 0.043478
#
#
#
# Size: 1315 Bits - FPR: 0.028986
#
#
#
# Size: 1325 Bits - FPR: 0.000000
#
#
#
# Size: 1335 Bits - FPR: 0.028986
#
#
#
# Size: 1345 Bits - FPR: 0.043478
#
#
#
# Size: 1355 Bits - FPR: 0.028986
#
#
#
# Size: 1365 Bits - FPR: 0.028986
#
#
#
# Size: 1375 Bits - FPR: 0.014493
#
#
#
# Size: 1385 Bits - FPR: 0.057971
#
#
#
# Size: 1395 Bits - FPR: 0.057971
#
#
#
# Size: 1405 Bits - FPR: 0.057971
#
#
#
# Size: 1415 Bits - FPR: 0.028986
#
#
#
# Size: 1425 Bits - FPR: 0.000000
#
#
#
# Size: 1435 Bits - FPR: 0.014493
#
#
#
# Size: 1445 Bits - FPR: 0.028986
#
#
#
# Size: 1455 Bits - FPR: 0.072464
#
#
#
# Size: 1465 Bits - FPR: 0.086957
#
#
#
# Size: 1475 Bits - FPR: 0.014493
#
#
#
# Size: 1485 Bits - FPR: 0.057971
#
#
#
# Size: 1495 Bits - FPR: 0.043478
#
#
#
# Size: 1505 Bits - FPR: 0.043478
#
#
#
# Size: 1515 Bits - FPR: 0.028986
#
#
#
# Size: 1525 Bits - FPR: 0.043478
#
#
#
# Size: 1535 Bits - FPR: 0.043478
#
#
#
# Size: 1545 Bits - FPR: 0.057971
#
#
#
# Size: 1555 Bits - FPR: 0.014493
#
#
#
# Size: 1565 Bits - FPR: 0.014493
#
#
#
# Size: 1575 Bits - FPR: 0.000000
#
#
#
# Size: 1585 Bits - FPR: 0.000000
#
#
#
# Size: 1595 Bits - FPR: 0.072464
#
#
#
# Size: 1605 Bits - FPR: 0.028986
#
#
#
# Size: 1615 Bits - FPR: 0.000000
#
#
#
# Size: 1625 Bits - FPR: 0.014493
#
#
#
# Size: 1635 Bits - FPR: 0.014493
#
#
#
# Size: 1645 Bits - FPR: 0.028986
#
#
#
# Size: 1655 Bits - FPR: 0.014493
#
#
#
# Size: 1665 Bits - FPR: 0.000000
#
#
#
# Size: 1675 Bits - FPR: 0.014493
#
#
#
# Size: 1685 Bits - FPR: 0.014493
#
#
#
# Size: 1695 Bits - FPR: 0.014493
#
#
#
# Size: 1705 Bits - FPR: 0.000000
#
#
#
# Size: 1715 Bits - FPR: 0.043478
#
#
#
# Size: 1725 Bits - FPR: 0.028986
#
#
#
# Size: 1735 Bits - FPR: 0.028986
#
#
#
# Size: 1745 Bits - FPR: 0.028986
#
#
#
# Size: 1755 Bits - FPR: 0.028986
#
#
#
# Size: 1765 Bits - FPR: 0.057971
#
#
#
# Size: 1775 Bits - FPR: 0.014493
#
#
#
# Size: 1785 Bits - FPR: 0.000000
#
#
#
# Size: 1795 Bits - FPR: 0.014493
#
#
#
# Size: 1805 Bits - FPR: 0.028986
#
#
#
# Size: 1815 Bits - FPR: 0.014493
#
#
#
# Size: 1825 Bits - FPR: 0.000000
#
#
#
# Size: 1835 Bits - FPR: 0.000000
#
#
#
# Size: 1845 Bits - FPR: 0.014493
#
#
#
# Size: 1855 Bits - FPR: 0.000000
#
#
#
# Size: 1865 Bits - FPR: 0.014493
#
#
#
# Size: 1875 Bits - FPR: 0.028986
#
#
#
# Size: 1885 Bits - FPR: 0.014493
#
#
#
# Size: 1895 Bits - FPR: 0.000000
#
#
#
# Size: 1905 Bits - FPR: 0.014493
#
#
#
# Size: 1915 Bits - FPR: 0.000000
#
#
#
# Size: 1925 Bits - FPR: 0.028986
#
#
#
# Size: 1935 Bits - FPR: 0.000000
#
#
#
# Size: 1945 Bits - FPR: 0.014493
#
#
#
# Size: 1955 Bits - FPR: 0.000000
#
#
#
# Size: 1965 Bits - FPR: 0.014493
#
#
#
# Size: 1975 Bits - FPR: 0.014493
#
#
#
# Size: 1985 Bits - FPR: 0.000000
#
#
#
# Size: 1995 Bits - FPR: 0.014493

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (165, 13)
# Size: 5 Bits - FPR: 0.000000
#
#
#
# Size: 15 Bits - FPR: 0.901449
#
#
#
# Size: 25 Bits - FPR: 0.695652
#
#
#
# Size: 35 Bits - FPR: 0.626087
#
#
#
# Size: 45 Bits - FPR: 0.686957
#
#
#
# Size: 55 Bits - FPR: 0.657971
#
#
#
# Size: 65 Bits - FPR: 0.681159
#
#
#
# Size: 75 Bits - FPR: 0.530435
#
#
#
# Size: 85 Bits - FPR: 0.568116
#
#
#
# Size: 95 Bits - FPR: 0.434783
#
#
#
# Size: 105 Bits - FPR: 0.556522
#
#
#
# Size: 115 Bits - FPR: 0.608696
#
#
#
# Size: 125 Bits - FPR: 0.565217
#
#
#
# Size: 135 Bits - FPR: 0.515942
#
#
#
# Size: 145 Bits - FPR: 0.466667
#
#
#
# Size: 155 Bits - FPR: 0.547826
#
#
#
# Size: 165 Bits - FPR: 0.411594
#
#
#
# Size: 175 Bits - FPR: 0.388406
#
#
#
# Size: 185 Bits - FPR: 0.391304
#
#
#
# Size: 195 Bits - FPR: 0.492754
#
#
#
# Size: 205 Bits - FPR: 0.318841
#
#
#
# Size: 215 Bits - FPR: 0.388406
#
#
#
# Size: 225 Bits - FPR: 0.394203
#
#
#
# Size: 235 Bits - FPR: 0.339130
#
#
#
# Size: 245 Bits - FPR: 0.391304
#
#
#
# Size: 255 Bits - FPR: 0.391304
#
#
#
# Size: 265 Bits - FPR: 0.318841
#
#
#
# Size: 275 Bits - FPR: 0.339130
#
#
#
# Size: 285 Bits - FPR: 0.391304
#
#
#
# Size: 295 Bits - FPR: 0.301449
#
#
#
# Size: 305 Bits - FPR: 0.295652
#
#
#
# Size: 315 Bits - FPR: 0.275362
#
#
#
# Size: 325 Bits - FPR: 0.507246
#
#
#
# Size: 335 Bits - FPR: 0.246377
#
#
#
# Size: 345 Bits - FPR: 0.402899
#
#
#
# Size: 355 Bits - FPR: 0.376812
#
#
#
# Size: 365 Bits - FPR: 0.463768
#
#
#
# Size: 375 Bits - FPR: 0.228986
#
#
#
# Size: 385 Bits - FPR: 0.315942
#
#
#
# Size: 395 Bits - FPR: 0.202899
#
#
#
# Size: 405 Bits - FPR: 0.315942
#
#
#
# Size: 415 Bits - FPR: 0.260870
#
#
#
# Size: 425 Bits - FPR: 0.278261
#
#
#
# Size: 435 Bits - FPR: 0.333333
#
#
#
# Size: 445 Bits - FPR: 0.292754
#
#
#
# Size: 455 Bits - FPR: 0.200000
#
#
#
# Size: 465 Bits - FPR: 0.289855
#
#
#
# Size: 475 Bits - FPR: 0.188406
#
#
#
# Size: 485 Bits - FPR: 0.191304
#
#
#
# Size: 495 Bits - FPR: 0.173913
#
#
#
# Size: 505 Bits - FPR: 0.249275
#
#
#
# Size: 515 Bits - FPR: 0.246377
#
#
#
# Size: 525 Bits - FPR: 0.156522
#
#
#
# Size: 535 Bits - FPR: 0.226087
#
#
#
# Size: 545 Bits - FPR: 0.188406
#
#
#
# Size: 555 Bits - FPR: 0.278261
#
#
#
# Size: 565 Bits - FPR: 0.214493
#
#
#
# Size: 575 Bits - FPR: 0.252174
#
#
#
# Size: 585 Bits - FPR: 0.202899
#
#
#
# Size: 595 Bits - FPR: 0.173913
#
#
#
# Size: 605 Bits - FPR: 0.162319
#
#
#
# Size: 615 Bits - FPR: 0.162319
#
#
#
# Size: 625 Bits - FPR: 0.124638
#
#
#
# Size: 635 Bits - FPR: 0.118841
#
#
#
# Size: 645 Bits - FPR: 0.130435
#
#
#
# Size: 655 Bits - FPR: 0.205797
#
#
#
# Size: 665 Bits - FPR: 0.127536
#
#
#
# Size: 675 Bits - FPR: 0.121739
#
#
#
# Size: 685 Bits - FPR: 0.202899
#
#
#
# Size: 695 Bits - FPR: 0.173913
#
#
#
# Size: 705 Bits - FPR: 0.202899
#
#
#
# Size: 715 Bits - FPR: 0.086957
#
#
#
# Size: 725 Bits - FPR: 0.139130
#
#
#
# Size: 735 Bits - FPR: 0.173913
#
#
#
# Size: 745 Bits - FPR: 0.028986
#
#
#
# Size: 755 Bits - FPR: 0.081159
#
#
#
# Size: 765 Bits - FPR: 0.101449
#
#
#
# Size: 775 Bits - FPR: 0.130435
#
#
#
# Size: 785 Bits - FPR: 0.113043
#
#
#
# Size: 795 Bits - FPR: 0.078261
#
#
#
# Size: 805 Bits - FPR: 0.133333
#
#
#
# Size: 815 Bits - FPR: 0.130435
#
#
#
# Size: 825 Bits - FPR: 0.127536
#
#
#
# Size: 835 Bits - FPR: 0.101449
#
#
#
# Size: 845 Bits - FPR: 0.057971
#
#
#
# Size: 855 Bits - FPR: 0.081159
#
#
#
# Size: 865 Bits - FPR: 0.110145
#
#
#
# Size: 875 Bits - FPR: 0.188406
#
#
#
# Size: 885 Bits - FPR: 0.115942
#
#
#
# Size: 895 Bits - FPR: 0.127536
#
#
#
# Size: 905 Bits - FPR: 0.057971
#
#
#
# Size: 915 Bits - FPR: 0.104348
#
#
#
# Size: 925 Bits - FPR: 0.101449
#
#
#
# Size: 935 Bits - FPR: 0.101449
#
#
#
# Size: 945 Bits - FPR: 0.101449
#
#
#
# Size: 955 Bits - FPR: 0.101449
#
#
#
# Size: 965 Bits - FPR: 0.130435
#
#
#
# Size: 975 Bits - FPR: 0.101449
#
#
#
# Size: 985 Bits - FPR: 0.072464
#
#
#
# Size: 995 Bits - FPR: 0.055072
#
#
#
# Size: 1005 Bits - FPR: 0.072464
#
#
#
# Size: 1015 Bits - FPR: 0.159420
#
#
#
# Size: 1025 Bits - FPR: 0.028986
#
#
#
# Size: 1035 Bits - FPR: 0.084058
#
#
#
# Size: 1045 Bits - FPR: 0.078261
#
#
#
# Size: 1055 Bits - FPR: 0.084058
#
#
#
# Size: 1065 Bits - FPR: 0.173913
#
#
#
# Size: 1075 Bits - FPR: 0.072464
#
#
#
# Size: 1085 Bits - FPR: 0.031884
#
#
#
# Size: 1095 Bits - FPR: 0.057971
#
#
#
# Size: 1105 Bits - FPR: 0.072464
#
#
#
# Size: 1115 Bits - FPR: 0.072464
#
#
#
# Size: 1125 Bits - FPR: 0.072464
#
#
#
# Size: 1135 Bits - FPR: 0.028986
#
#
#
# Size: 1145 Bits - FPR: 0.101449
#
#
#
# Size: 1155 Bits - FPR: 0.014493
#
#
#
# Size: 1165 Bits - FPR: 0.057971
#
#
#
# Size: 1175 Bits - FPR: 0.072464
#
#
#
# Size: 1185 Bits - FPR: 0.057971
#
#
#
# Size: 1195 Bits - FPR: 0.043478
#
#
#
# Size: 1205 Bits - FPR: 0.057971
#
#
#
# Size: 1215 Bits - FPR: 0.043478
#
#
#
# Size: 1225 Bits - FPR: 0.014493
#
#
#
# Size: 1235 Bits - FPR: 0.057971
#
#
#
# Size: 1245 Bits - FPR: 0.043478
#
#
#
# Size: 1255 Bits - FPR: 0.028986
#
#
#
# Size: 1265 Bits - FPR: 0.101449
#
#
#
# Size: 1275 Bits - FPR: 0.028986
#
#
#
# Size: 1285 Bits - FPR: 0.057971
#
#
#
# Size: 1295 Bits - FPR: 0.057971
#
#
#
# Size: 1305 Bits - FPR: 0.028986
#
#
#
# Size: 1315 Bits - FPR: 0.057971
#
#
#
# Size: 1325 Bits - FPR: 0.028986
#
#
#
# Size: 1335 Bits - FPR: 0.014493
#
#
#
# Size: 1345 Bits - FPR: 0.043478
#
#
#
# Size: 1355 Bits - FPR: 0.072464
#
#
#
# Size: 1365 Bits - FPR: 0.057971
#
#
#
# Size: 1375 Bits - FPR: 0.028986
#
#
#
# Size: 1385 Bits - FPR: 0.028986
#
#
#
# Size: 1395 Bits - FPR: 0.057971
#
#
#
# Size: 1405 Bits - FPR: 0.043478
#
#
#
# Size: 1415 Bits - FPR: 0.014493
#
#
#
# Size: 1425 Bits - FPR: 0.000000
#
#
#
# Size: 1435 Bits - FPR: 0.057971
#
#
#
# Size: 1445 Bits - FPR: 0.043478
#
#
#
# Size: 1455 Bits - FPR: 0.028986
#
#
#
# Size: 1465 Bits - FPR: 0.000000
#
#
#
# Size: 1475 Bits - FPR: 0.000000
#
#
#
# Size: 1485 Bits - FPR: 0.072464
#
#
#
# Size: 1495 Bits - FPR: 0.028986
#
#
#
# Size: 1505 Bits - FPR: 0.000000
#
#
#
# Size: 1515 Bits - FPR: 0.014493
#
#
#
# Size: 1525 Bits - FPR: 0.057971
#
#
#
# Size: 1535 Bits - FPR: 0.014493
#
#
#
# Size: 1545 Bits - FPR: 0.000000
#
#
#
# Size: 1555 Bits - FPR: 0.014493
#
#
#
# Size: 1565 Bits - FPR: 0.014493
#
#
#
# Size: 1575 Bits - FPR: 0.000000
#
#
#
# Size: 1585 Bits - FPR: 0.028986
#
#
#
# Size: 1595 Bits - FPR: 0.043478
#
#
#
# Size: 1605 Bits - FPR: 0.000000
#
#
#
# Size: 1615 Bits - FPR: 0.043478
#
#
#
# Size: 1625 Bits - FPR: 0.043478
#
#
#
# Size: 1635 Bits - FPR: 0.028986
#
#
#
# Size: 1645 Bits - FPR: 0.028986
#
#
#
# Size: 1655 Bits - FPR: 0.000000
#
#
#
# Size: 1665 Bits - FPR: 0.028986
#
#
#
# Size: 1675 Bits - FPR: 0.000000
#
#
#
# Size: 1685 Bits - FPR: 0.028986
#
#
#
# Size: 1695 Bits - FPR: 0.043478
#
#
#
# Size: 1705 Bits - FPR: 0.000000
#
#
#
# Size: 1715 Bits - FPR: 0.028986
#
#
#
# Size: 1725 Bits - FPR: 0.000000
#
#
#
# Size: 1735 Bits - FPR: 0.014493
#
#
#
# Size: 1745 Bits - FPR: 0.000000
#
#
#
# Size: 1755 Bits - FPR: 0.014493
#
#
#
# Size: 1765 Bits - FPR: 0.000000
#
#
#
# Size: 1775 Bits - FPR: 0.014493
#
#
#
# Size: 1785 Bits - FPR: 0.014493
#
#
#
# Size: 1795 Bits - FPR: 0.014493
#
#
#
# Size: 1805 Bits - FPR: 0.000000
#
#
#
# Size: 1815 Bits - FPR: 0.000000
#
#
#
# Size: 1825 Bits - FPR: 0.014493
#
#
#
# Size: 1835 Bits - FPR: 0.014493
#
#
#
# Size: 1845 Bits - FPR: 0.000000
#
#
#
# Size: 1855 Bits - FPR: 0.000000
#
#
#
# Size: 1865 Bits - FPR: 0.043478
#
#
#
# Size: 1875 Bits - FPR: 0.014493
#
#
#
# Size: 1885 Bits - FPR: 0.014493
#
#
#
# Size: 1895 Bits - FPR: 0.000000
#
#
#
# Size: 1905 Bits - FPR: 0.000000
#
#
#
# Size: 1915 Bits - FPR: 0.000000
#
#
#
# Size: 1925 Bits - FPR: 0.000000
#
#
#
# Size: 1935 Bits - FPR: 0.000000
#
#
#
# Size: 1945 Bits - FPR: 0.000000
#
#
#
# Size: 1955 Bits - FPR: 0.000000
#
#
#
# Size: 1965 Bits - FPR: 0.000000
#
#
#
# Size: 1975 Bits - FPR: 0.028986
#
#
#
# Size: 1985 Bits - FPR: 0.000000
#
#
#
# Size: 1995 Bits - FPR: 0.028986

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (165, 13)
# Size: 5 Bits - FPR: 0.000000
#
#
#
# Size: 15 Bits - FPR: 0.852174
#
#
#
# Size: 25 Bits - FPR: 0.771014
#
#
#
# Size: 35 Bits - FPR: 0.744928
#
#
#
# Size: 45 Bits - FPR: 0.640580
#
#
#
# Size: 55 Bits - FPR: 0.623188
#
#
#
# Size: 65 Bits - FPR: 0.600000
#
#
#
# Size: 75 Bits - FPR: 0.605797
#
#
#
# Size: 85 Bits - FPR: 0.463768
#
#
#
# Size: 95 Bits - FPR: 0.739130
#
#
#
# Size: 105 Bits - FPR: 0.559420
#
#
#
# Size: 115 Bits - FPR: 0.478261
#
#
#
# Size: 125 Bits - FPR: 0.492754
#
#
#
# Size: 135 Bits - FPR: 0.498551
#
#
#
# Size: 145 Bits - FPR: 0.550725
#
#
#
# Size: 155 Bits - FPR: 0.362319
#
#
#
# Size: 165 Bits - FPR: 0.385507
#
#
#
# Size: 175 Bits - FPR: 0.342029
#
#
#
# Size: 185 Bits - FPR: 0.426087
#
#
#
# Size: 195 Bits - FPR: 0.368116
#
#
#
# Size: 205 Bits - FPR: 0.449275
#
#
#
# Size: 215 Bits - FPR: 0.434783
#
#
#
# Size: 225 Bits - FPR: 0.289855
#
#
#
# Size: 235 Bits - FPR: 0.402899
#
#
#
# Size: 245 Bits - FPR: 0.344928
#
#
#
# Size: 255 Bits - FPR: 0.368116
#
#
#
# Size: 265 Bits - FPR: 0.339130
#
#
#
# Size: 275 Bits - FPR: 0.228986
#
#
#
# Size: 285 Bits - FPR: 0.281159
#
#
#
# Size: 295 Bits - FPR: 0.281159
#
#
#
# Size: 305 Bits - FPR: 0.246377
#
#
#
# Size: 315 Bits - FPR: 0.260870
#
#
#
# Size: 325 Bits - FPR: 0.292754
#
#
#
# Size: 335 Bits - FPR: 0.284058
#
#
#
# Size: 345 Bits - FPR: 0.226087
#
#
#
# Size: 355 Bits - FPR: 0.304348
#
#
#
# Size: 365 Bits - FPR: 0.252174
#
#
#
# Size: 375 Bits - FPR: 0.269565
#
#
#
# Size: 385 Bits - FPR: 0.298551
#
#
#
# Size: 395 Bits - FPR: 0.260870
#
#
#
# Size: 405 Bits - FPR: 0.333333
#
#
#
# Size: 415 Bits - FPR: 0.260870
#
#
#
# Size: 425 Bits - FPR: 0.197101
#
#
#
# Size: 435 Bits - FPR: 0.281159
#
#
#
# Size: 445 Bits - FPR: 0.240580
#
#
#
# Size: 455 Bits - FPR: 0.246377
#
#
#
# Size: 465 Bits - FPR: 0.173913
#
#
#
# Size: 475 Bits - FPR: 0.255072
#
#
#
# Size: 485 Bits - FPR: 0.255072
#
#
#
# Size: 495 Bits - FPR: 0.231884
#
#
#
# Size: 505 Bits - FPR: 0.249275
#
#
#
# Size: 515 Bits - FPR: 0.101449
#
#
#
# Size: 525 Bits - FPR: 0.176812
#
#
#
# Size: 535 Bits - FPR: 0.217391
#
#
#
# Size: 545 Bits - FPR: 0.168116
#
#
#
# Size: 555 Bits - FPR: 0.217391
#
#
#
# Size: 565 Bits - FPR: 0.205797
#
#
#
# Size: 575 Bits - FPR: 0.231884
#
#
#
# Size: 585 Bits - FPR: 0.231884
#
#
#
# Size: 595 Bits - FPR: 0.121739
#
#
#
# Size: 605 Bits - FPR: 0.217391
#
#
#
# Size: 615 Bits - FPR: 0.197101
#
#
#
# Size: 625 Bits - FPR: 0.217391
#
#
#
# Size: 635 Bits - FPR: 0.275362
#
#
#
# Size: 645 Bits - FPR: 0.101449
#
#
#
# Size: 655 Bits - FPR: 0.202899
#
#
#
# Size: 665 Bits - FPR: 0.144928
#
#
#
# Size: 675 Bits - FPR: 0.168116
#
#
#
# Size: 685 Bits - FPR: 0.115942
#
#
#
# Size: 695 Bits - FPR: 0.231884
#
#
#
# Size: 705 Bits - FPR: 0.115942
#
#
#
# Size: 715 Bits - FPR: 0.144928
#
#
#
# Size: 725 Bits - FPR: 0.069565
#
#
#
# Size: 735 Bits - FPR: 0.081159
#
#
#
# Size: 745 Bits - FPR: 0.246377
#
#
#
# Size: 755 Bits - FPR: 0.072464
#
#
#
# Size: 765 Bits - FPR: 0.162319
#
#
#
# Size: 775 Bits - FPR: 0.150725
#
#
#
# Size: 785 Bits - FPR: 0.121739
#
#
#
# Size: 795 Bits - FPR: 0.072464
#
#
#
# Size: 805 Bits - FPR: 0.028986
#
#
#
# Size: 815 Bits - FPR: 0.086957
#
#
#
# Size: 825 Bits - FPR: 0.081159
#
#
#
# Size: 835 Bits - FPR: 0.086957
#
#
#
# Size: 845 Bits - FPR: 0.060870
#
#
#
# Size: 855 Bits - FPR: 0.101449
#
#
#
# Size: 865 Bits - FPR: 0.130435
#
#
#
# Size: 875 Bits - FPR: 0.153623
#
#
#
# Size: 885 Bits - FPR: 0.115942
#
#
#
# Size: 895 Bits - FPR: 0.057971
#
#
#
# Size: 905 Bits - FPR: 0.202899
#
#
#
# Size: 915 Bits - FPR: 0.069565
#
#
#
# Size: 925 Bits - FPR: 0.063768
#
#
#
# Size: 935 Bits - FPR: 0.081159
#
#
#
# Size: 945 Bits - FPR: 0.101449
#
#
#
# Size: 955 Bits - FPR: 0.098551
#
#
#
# Size: 965 Bits - FPR: 0.098551
#
#
#
# Size: 975 Bits - FPR: 0.072464
#
#
#
# Size: 985 Bits - FPR: 0.115942
#
#
#
# Size: 995 Bits - FPR: 0.057971
#
#
#
# Size: 1005 Bits - FPR: 0.139130
#
#
#
# Size: 1015 Bits - FPR: 0.115942
#
#
#
# Size: 1025 Bits - FPR: 0.028986
#
#
#
# Size: 1035 Bits - FPR: 0.086957
#
#
#
# Size: 1045 Bits - FPR: 0.028986
#
#
#
# Size: 1055 Bits - FPR: 0.057971
#
#
#
# Size: 1065 Bits - FPR: 0.028986
#
#
#
# Size: 1075 Bits - FPR: 0.040580
#
#
#
# Size: 1085 Bits - FPR: 0.060870
#
#
#
# Size: 1095 Bits - FPR: 0.101449
#
#
#
# Size: 1105 Bits - FPR: 0.069565
#
#
#
# Size: 1115 Bits - FPR: 0.072464
#
#
#
# Size: 1125 Bits - FPR: 0.069565
#
#
#
# Size: 1135 Bits - FPR: 0.028986
#
#
#
# Size: 1145 Bits - FPR: 0.057971
#
#
#
# Size: 1155 Bits - FPR: 0.072464
#
#
#
# Size: 1165 Bits - FPR: 0.086957
#
#
#
# Size: 1175 Bits - FPR: 0.066667
#
#
#
# Size: 1185 Bits - FPR: 0.057971
#
#
#
# Size: 1195 Bits - FPR: 0.031884
#
#
#
# Size: 1205 Bits - FPR: 0.014493
#
#
#
# Size: 1215 Bits - FPR: 0.057971
#
#
#
# Size: 1225 Bits - FPR: 0.043478
#
#
#
# Size: 1235 Bits - FPR: 0.028986
#
#
#
# Size: 1245 Bits - FPR: 0.072464
#
#
#
# Size: 1255 Bits - FPR: 0.028986
#
#
#
# Size: 1265 Bits - FPR: 0.043478
#
#
#
# Size: 1275 Bits - FPR: 0.086957
#
#
#
# Size: 1285 Bits - FPR: 0.057971
#
#
#
# Size: 1295 Bits - FPR: 0.043478
#
#
#
# Size: 1305 Bits - FPR: 0.043478
#
#
#
# Size: 1315 Bits - FPR: 0.014493
#
#
#
# Size: 1325 Bits - FPR: 0.057971
#
#
#
# Size: 1335 Bits - FPR: 0.014493
#
#
#
# Size: 1345 Bits - FPR: 0.014493
#
#
#
# Size: 1355 Bits - FPR: 0.028986
#
#
#
# Size: 1365 Bits - FPR: 0.014493
#
#
#
# Size: 1375 Bits - FPR: 0.028986
#
#
#
# Size: 1385 Bits - FPR: 0.028986
#
#
#
# Size: 1395 Bits - FPR: 0.043478
#
#
#
# Size: 1405 Bits - FPR: 0.014493
#
#
#
# Size: 1415 Bits - FPR: 0.028986
#
#
#
# Size: 1425 Bits - FPR: 0.000000
#
#
#
# Size: 1435 Bits - FPR: 0.057971
#
#
#
# Size: 1445 Bits - FPR: 0.028986
#
#
#
# Size: 1455 Bits - FPR: 0.014493
#
#
#
# Size: 1465 Bits - FPR: 0.028986
#
#
#
# Size: 1475 Bits - FPR: 0.014493
#
#
#
# Size: 1485 Bits - FPR: 0.028986
#
#
#
# Size: 1495 Bits - FPR: 0.028986
#
#
#
# Size: 1505 Bits - FPR: 0.014493
#
#
#
# Size: 1515 Bits - FPR: 0.000000
#
#
#
# Size: 1525 Bits - FPR: 0.028986
#
#
#
# Size: 1535 Bits - FPR: 0.028986
#
#
#
# Size: 1545 Bits - FPR: 0.014493
#
#
#
# Size: 1555 Bits - FPR: 0.014493
#
#
#
# Size: 1565 Bits - FPR: 0.014493
#
#
#
# Size: 1575 Bits - FPR: 0.014493
#
#
#
# Size: 1585 Bits - FPR: 0.014493
#
#
#
# Size: 1595 Bits - FPR: 0.028986
#
#
#
# Size: 1605 Bits - FPR: 0.028986
#
#
#
# Size: 1615 Bits - FPR: 0.014493
#
#
#
# Size: 1625 Bits - FPR: 0.057971
#
#
#
# Size: 1635 Bits - FPR: 0.014493
#
#
#
# Size: 1645 Bits - FPR: 0.028986
#
#
#
# Size: 1655 Bits - FPR: 0.014493
#
#
#
# Size: 1665 Bits - FPR: 0.014493
#
#
#
# Size: 1675 Bits - FPR: 0.014493
#
#
#
# Size: 1685 Bits - FPR: 0.043478
#
#
#
# Size: 1695 Bits - FPR: 0.014493
#
#
#
# Size: 1705 Bits - FPR: 0.014493
#
#
#
# Size: 1715 Bits - FPR: 0.000000
#
#
#
# Size: 1725 Bits - FPR: 0.014493
#
#
#
# Size: 1735 Bits - FPR: 0.014493
#
#
#
# Size: 1745 Bits - FPR: 0.043478
#
#
#
# Size: 1755 Bits - FPR: 0.014493
#
#
#
# Size: 1765 Bits - FPR: 0.000000
#
#
#
# Size: 1775 Bits - FPR: 0.000000
#
#
#
# Size: 1785 Bits - FPR: 0.000000
#
#
#
# Size: 1795 Bits - FPR: 0.000000
#
#
#
# Size: 1805 Bits - FPR: 0.000000
#
#
#
# Size: 1815 Bits - FPR: 0.014493
#
#
#
# Size: 1825 Bits - FPR: 0.000000
#
#
#
# Size: 1835 Bits - FPR: 0.014493
#
#
#
# Size: 1845 Bits - FPR: 0.014493
#
#
#
# Size: 1855 Bits - FPR: 0.014493
#
#
#
# Size: 1865 Bits - FPR: 0.000000
#
#
#
# Size: 1875 Bits - FPR: 0.000000
#
#
#
# Size: 1885 Bits - FPR: 0.000000
#
#
#
# Size: 1895 Bits - FPR: 0.000000
#
#
#
# Size: 1905 Bits - FPR: 0.014493
#
#
#
# Size: 1915 Bits - FPR: 0.000000
#
#
#
# Size: 1925 Bits - FPR: 0.000000
#
#
#
# Size: 1935 Bits - FPR: 0.000000
#
#
#
# Size: 1945 Bits - FPR: 0.014493
#
#
#
# Size: 1955 Bits - FPR: 0.000000
#
#
#
# Size: 1965 Bits - FPR: 0.000000
#
#
#
# Size: 1975 Bits - FPR: 0.014493
#
#
#
# Size: 1985 Bits - FPR: 0.000000
#
#
#
# Size: 1995 Bits - FPR: 0.000000

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=fpr_values, err_style="band",label = "Projection",linewidth = 1.5,color="g")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
plt.plot(size_values,fpr_values)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()     #unit positive vectors

# %%
plt.plot(size_values,fpr_values)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()        # non unit positive vectors

# %%
plt.plot(size_values,fpr_values)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()        #non unit vectors

# %%
plt.plot(size_values,fpr_values)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()        #unit values

# %% [markdown]
# # Normal Bloom Filter Values

# %%
def ideal_fpr(m,n):
    k = eff_k(m,n,1)
    return (1-(1-(1/m))**(n*k))**k

# %%
print(sum(y_train))
print(len(y_train))
# Out:
# [165]
# 234

# %%
n = sum(y_train)
y_ideal=[]
for x in size_values:
    y_ideal+=[float(ideal_fpr(x,n))]
print(len(y_ideal))
print(n)
# Out:
# 600
# [165]

# %%
plt.plot(size_values,y_ideal)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=y_ideal, err_style="band",label = "Ideal",linewidth = 1.5,color="r")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %% [markdown]
# # FPR Comparison between Projection Model and Normal Bloom Filter

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
#unit positive vectors

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
# non unit positive vectors

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
# non unit vectors

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
# unit vectors

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=fpr_values, err_style="band",label = "Projection",linewidth = 1.5,color="g")
sns.lineplot(x=size_values, y=y_ideal, err_style="band",label = "Ideal",linewidth = 1.5,color="r")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %% [markdown]
# #  FPR Comparison between Kraska Hash Model, Projection Model and Normal Bloom Filter

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.plot(size_values_kraska,fpr_values_kraska,color='blue')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
# Blue- Kraska Hash Model

# %% [markdown]
# # Size comparisons

# %%
fpr_values_projection = []

# %%
def get_data_points_Projection2(x_train,x_test,y_train,epochs,fpr_values,size_values_kraska):
    input_dim = x_train.shape[1]
    n = sum(y_train)
    x_pos = x_train[(y_train==1).reshape(-1)]
    print(x_pos.shape)
    x_neg = x_train[(y_train==0).reshape(-1)]
    for i in size_values_kraska:
        m = i
        k = eff_k(m,n,1)
        fpr = 1
        tempbf = Projection_BloomFilter(m,k,input_dim)
        for j in range(0,epochs):
            bf = Projection_BloomFilter(m,k,input_dim)
            bf.bulk_add(x_pos)
            temp = find_fpr(bf,x_pos,x_neg)
            if(fpr>temp):
                fpr = temp
                tempbf=bf
        fpr_test=find_fpr2(tempbf,x_test)
        print("Size: %d Bits - FPR: %f \n\n\n" % (m,fpr_test))
        fpr_values += [fpr_test]

# %%
get_data_points_Projection2(x_train,x_test,y_train,100,fpr_values_projection,size_values_kraska)
# Out:
# (165, 13)
# Size: 1025 Bits - FPR: 0.144928
#
#
#
# Size: 1985 Bits - FPR: 0.028986
#
#
#
# Size: 2945 Bits - FPR: 0.000000
#
#
#
# Size: 3905 Bits - FPR: 0.000000
#
#
#
# Size: 4865 Bits - FPR: 0.000000
#
#
#
# Size: 5825 Bits - FPR: 0.000000
#
#
#
# Size: 6785 Bits - FPR: 0.000000
#
#
#
# Size: 7745 Bits - FPR: 0.000000
#
#
#
# Size: 8705 Bits - FPR: 0.000000
#
#
#
# Size: 9665 Bits - FPR: 0.000000
#
#
#
# Size: 10625 Bits - FPR: 0.000000
#
#
#
# Size: 11585 Bits - FPR: 0.000000
#
#
#
# Size: 12545 Bits - FPR: 0.000000
#
#
#
# Size: 13505 Bits - FPR: 0.000000
#
#
#
# Size: 14465 Bits - FPR: 0.000000
#
#
#
# Size: 15425 Bits - FPR: 0.000000
#
#
#
# Size: 16385 Bits - FPR: 0.000000
#
#
#
# Size: 17345 Bits - FPR: 0.000000
#
#
#
# Size: 18305 Bits - FPR: 0.000000
#
#
#
# Size: 19265 Bits - FPR: 0.000000
#
#
#
# Size: 1025 Bits - FPR: 0.115942
#
#
#
# Size: 1985 Bits - FPR: 0.014493
#
#
#
# Size: 2945 Bits - FPR: 0.000000
#
#
#
# Size: 3905 Bits - FPR: 0.000000
#
#
#
# Size: 4865 Bits - FPR: 0.000000
#
#
#
# Size: 5825 Bits - FPR: 0.000000
#
#
#
# Size: 6785 Bits - FPR: 0.000000
#
#
#
# Size: 7745 Bits - FPR: 0.000000
#
#
#
# Size: 8705 Bits - FPR: 0.000000
#
#
#
# Size: 9665 Bits - FPR: 0.000000
#
#
#
# Size: 10625 Bits - FPR: 0.000000
#
#
#
# Size: 11585 Bits - FPR: 0.000000
#
#
#
# Size: 12545 Bits - FPR: 0.000000
#
#
#
# Size: 13505 Bits - FPR: 0.000000
#
#
#
# Size: 14465 Bits - FPR: 0.000000
#
#
#
# Size: 15425 Bits - FPR: 0.000000
#
#
#
# Size: 16385 Bits - FPR: 0.000000
#
#
#
# Size: 17345 Bits - FPR: 0.000000
#
#
#
# Size: 18305 Bits - FPR: 0.000000
#
#
#
# Size: 19265 Bits - FPR: 0.000000
#
#
#
# Size: 1025 Bits - FPR: 0.101449
#
#
#
# Size: 1985 Bits - FPR: 0.014493
#
#
#
# Size: 2945 Bits - FPR: 0.000000
#
#
#
# Size: 3905 Bits - FPR: 0.000000
#
#
#
# Size: 4865 Bits - FPR: 0.000000
#
#
#
# Size: 5825 Bits - FPR: 0.000000
#
#
#
# Size: 6785 Bits - FPR: 0.000000
#
#
#
# Size: 7745 Bits - FPR: 0.000000
#
#
#
# Size: 8705 Bits - FPR: 0.000000
#
#
#
# Size: 9665 Bits - FPR: 0.000000
#
#
#
# Size: 10625 Bits - FPR: 0.000000
#
#
#
# Size: 11585 Bits - FPR: 0.000000
#
#
#
# Size: 12545 Bits - FPR: 0.000000
#
#
#
# Size: 13505 Bits - FPR: 0.000000
#
#
#
# Size: 14465 Bits - FPR: 0.000000
#
#
#
# Size: 15425 Bits - FPR: 0.000000
#
#
#
# Size: 16385 Bits - FPR: 0.000000
#
#
#
# Size: 17345 Bits - FPR: 0.000000
#
#
#
# Size: 18305 Bits - FPR: 0.000000
#
#
#
# Size: 19265 Bits - FPR: 0.000000

# %%
len(size_values_kraska)/3
# Out:
# 20.0

# %%
n = sum(y_train)
y_ideal_k=[]
for x in size_values_kraska:
    y_ideal_k+=[float(ideal_fpr(x,n))]
print(len(y_ideal_k))
print(n)
# Out:
# 60
# [165]

# %%
plt.plot(size_values_kraska,y_ideal,color='red') #ideal
plt.plot(size_values_kraska,fpr_values,color='green') #projection
plt.plot(size_values_kraska,fpr_values_kraska,color='blue') #kraska
plt.xlabel('Size(in bits)')
plt.ylabel('FPR')
plt.show()

# %%
plt.plot(size_values_kraska,y_ideal,color='red') #ideal
plt.plot(size_values_kraska,fpr_values,color='green') #projection
plt.xlabel('Size(in bits)')
plt.ylabel('FPR')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=fpr_values_kraska, err_style="band",marker="o",label = "Kraska",linestyle= "--",markersize=10)
sns.lineplot(x=size_values_kraska, y=y_ideal_k, err_style="band",marker='>',label = "Ideal",linestyle= ":",markersize = 10)
sns.lineplot(x=size_values_kraska, y=fpr_values_projection, err_style="band",marker='<',label = "Projection",linestyle= "-.",markersize = 10)
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=y_ideal_k, err_style="band",marker='>',label = "Ideal",linestyle= ":",markersize = 10,color="r")
sns.lineplot(x=size_values_kraska, y=fpr_values_projection, err_style="band",marker='<',label = "Projection",linestyle= "-.",markersize = 10,color="g")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()
