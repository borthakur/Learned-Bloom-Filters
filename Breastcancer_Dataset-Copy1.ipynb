# %%
from bitarray import bitarray
import random
import numpy as np
import math

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %%
import pandas as pd
import os

# %%
from sklearn import datasets

# %%
bcancer = datasets.load_breast_cancer()
X = bcancer.data  
y = bcancer.target
X = StandardScaler().fit_transform(X)

# %%
x_neg=X[y==0]
x_pos=X[y==1]
y_pos=y[y==1]
y_neg=y[y==0]
np.random.shuffle(x_neg)
print(x_neg.shape)
print(x_pos.shape)
# Out:
# (212, 30)
# (357, 30)

# %%
indices=np.arange(106)
#x_train=np.array(x_neg[0:106])[indices]
y_train=y_neg[0:106]
x_train=np.concatenate((np.array(x_neg[0:106])[indices],x_pos)).reshape(-1,30)
y_train=np.concatenate((y_train,y_pos)).reshape(-1,1)

# %%
x_test = x_neg[106:212].reshape(-1,30)
y_test = y_neg[106:212].reshape(-1,1)

# %%
fpr_values_kraska = []
size_values_kraska = []

# %% [markdown]
# # Kraska Hash Model

# %%
class Kraska_Hash_BloomFilter:
    
    def __init__(self, size, model): #hash count is 1
        self.size = size
      #  self.hash_count = hash_count
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)
        self.model=model #classifier model associated as hash function
        
    def add(self, num):
        #for seed in range(1,self.hash_count+1):
            #result = mmh3.hash(str(num), seed) % self.size
        result=math.floor(model.predict(num)[0]*(self.size-1))    
        self.bit_array[result] = 1
            
    def lookup(self, num):
        #for seed in range(1,self.hash_count+1):
            #result = mmh3.hash(str(num), seed) % self.size
        result=math.floor(self.model.predict(num)[0]*(self.size-1))    
        if self.bit_array[result] == 0:
                return False
        return True

    def add_init(self,x_train,y_train):
        pred = self.model.predict(x_train)
        for i in range(len(pred)):
            if(y_train[i]==1):
                result = math.floor(pred[i][0]*(self.size-1))
                self.bit_array[result] = 1

    def predict(self,x):
        initpred = self.model.predict(x)
        indexes = []
        for i in range(len(initpred)):
            indexes += [math.floor(initpred[i][0]*(self.size-1))]
        pred = []
        for i in indexes:
            pred += [self.bit_array[i]]
        return np.array(pred)

#adds ratio r of an array of random integers of size n to bloom filter bf(input : bf,size,ratio; output: data array)
def addrandom(bf,n,r):
    data=np.empty(n,dtype=int)
    for i in range(0,n):
        data[i]=random.randint(0, 100000000)
    for j in range(0,int(n*r)):
        bf.add(data[j])
    return data

#(Input:bloom filter,number array,ratio of positives; Output:(-1) for false negative, otherwise fpr)
def fpr_kraska_hash(bf,x_test,y_test):
    pred = bf.predict(x_test)
    tn, fp, fn, tp = confusion_matrix(y_test,pred,labels=[False,True]).ravel() 
    return fp/(fp+tn)

#(Input:bloom filter size, total random numbers, ratio of number inserted; Output:efficient number of hash functions)
def eff_k(m,n,r):
    k=int(m/(int(n*r))*math.log(2))
    if(k==0):
        return 1
    return k

#(Input:size of bloom filter, number of hash functions, total numbers, ratio of numbers inserted; Output: fpr)
def find_fpr(m,model,n,r):
    bf=Kraska_Hash_BloomFilter(model,m)
    data=addrandom(bf,n,r)
    return fpr(bf,data,r)

#(Input:size of bloom filter, total numbers, ratio of numbers inserted; Output: prints inputs and fpr)
def outputs(m,n,r):
    find_fpr(m,model,n,r)
    #print("For m=%d, k=%d, n=%d, r=%.3f: fpr=%.3f"%(m,k,n,r,find_fpr(m,k,n,r)))

# %%
def get_data_points_Kraska(x_train,y_train,x_test,y_test,init_size,diff,num,epochs,fpr_values_kraska,size_values_kraska):
    batch_size = len(x_train)
    input_dim = x_train.shape[1]
    additional_metrics = ['acc']
    loss_function = BinaryCrossentropy()
    optimizer = Adam()
    verbosity_mode = 0
    average_over = 3   # Increase to make the graph smoother
    for i in range(0,num):
        layer_size = init_size + (diff*i)
        number_of_epochs = epochs
        sum_fpr = 0
        model_size = ((input_dim+1)*layer_size + (layer_size+1))*32
        m = int(model_size) + 1
        net_size = model_size + m

        for j in range(0,average_over):
            model = Sequential()
            model.add(Dense(layer_size,input_dim=input_dim,activation='relu'))
            model.add(Dense(1,activation='sigmoid'))
            model.compile(optimizer=optimizer, loss=loss_function, metrics=additional_metrics)
            history = model.fit(x_train, y_train, batch_size = batch_size, epochs=number_of_epochs, verbose=verbosity_mode)
            if(j==0):
                print("Number of nodes: %d" %(init_size + (diff*i)))
                plt.plot(history.history['acc'])
                plt.title('model accuracy')
                plt.ylabel('accuracy')
                plt.xlabel('epoch')
                plt.show()
                plt.plot(history.history['loss'])
                plt.title('model loss')
                plt.ylabel('loss')
                plt.xlabel('epoch')
                plt.show()
            
            bf=Kraska_Hash_BloomFilter(m,model)
            bf.add_init(x_train,y_train)
            sum_fpr += fpr_kraska_hash(bf,x_test,y_test)
        
        fpr = sum_fpr/average_over

        print("Size: %f bits - FPR: %f \n\n\n" % (net_size,fpr))
        fpr_values_kraska += [fpr]
        size_values_kraska += [net_size]

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# WARNING:tensorflow:From /Users/aditijain/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/aditijain/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Number of nodes: 1
# Size: 2113.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 2
# Size: 4161.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 3
# Size: 6209.000000 bits - FPR: 0.040881
#
#
#
# Number of nodes: 4
# Size: 8257.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 5
# Size: 10305.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 6
# Size: 12353.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 7
# Size: 14401.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 8
# Size: 16449.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 9
# Size: 18497.000000 bits - FPR: 0.037736
#
#
#
# Number of nodes: 10
# Size: 20545.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 11
# Size: 22593.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 12
# Size: 24641.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 13
# Size: 26689.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 14
# Size: 28737.000000 bits - FPR: 0.034591
#
#
#
# Number of nodes: 15
# Size: 30785.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 16
# Size: 32833.000000 bits - FPR: 0.034591
#
#
#
# Number of nodes: 17
# Size: 34881.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 18
# Size: 36929.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 19
# Size: 38977.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 20
# Size: 41025.000000 bits - FPR: 0.031447

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# Number of nodes: 1
# Size: 2113.000000 bits - FPR: 0.034591
#
#
#
# Number of nodes: 2
# Size: 4161.000000 bits - FPR: 0.034591
#
#
#
# Number of nodes: 3
# Size: 6209.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 4
# Size: 8257.000000 bits - FPR: 0.037736
#
#
#
# Number of nodes: 5
# Size: 10305.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 6
# Size: 12353.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 7
# Size: 14401.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 8
# Size: 16449.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 9
# Size: 18497.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 10
# Size: 20545.000000 bits - FPR: 0.018868
#
#
#
# Number of nodes: 11
# Size: 22593.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 12
# Size: 24641.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 13
# Size: 26689.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 14
# Size: 28737.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 15
# Size: 30785.000000 bits - FPR: 0.034591
#
#
#
# Number of nodes: 16
# Size: 32833.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 17
# Size: 34881.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 18
# Size: 36929.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 19
# Size: 38977.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 20
# Size: 41025.000000 bits - FPR: 0.018868

# %%
get_data_points_Kraska(x_train,y_train,x_test,y_test,1,1,20,3000,fpr_values_kraska,size_values_kraska)
# Out:
# Number of nodes: 1
# Size: 2113.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 2
# Size: 4161.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 3
# Size: 6209.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 4
# Size: 8257.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 5
# Size: 10305.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 6
# Size: 12353.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 7
# Size: 14401.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 8
# Size: 16449.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 9
# Size: 18497.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 10
# Size: 20545.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 11
# Size: 22593.000000 bits - FPR: 0.040881
#
#
#
# Number of nodes: 12
# Size: 24641.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 13
# Size: 26689.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 14
# Size: 28737.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 15
# Size: 30785.000000 bits - FPR: 0.028302
#
#
#
# Number of nodes: 16
# Size: 32833.000000 bits - FPR: 0.025157
#
#
#
# Number of nodes: 17
# Size: 34881.000000 bits - FPR: 0.031447
#
#
#
# Number of nodes: 18
# Size: 36929.000000 bits - FPR: 0.022013
#
#
#
# Number of nodes: 19
# Size: 38977.000000 bits - FPR: 0.037736
#
#
#
# Number of nodes: 20
# Size: 41025.000000 bits - FPR: 0.025157

# %%
plt.plot(size_values_kraska,fpr_values_kraska)
plt.title('FPRs')
plt.xlabel('Size(in bits)')
plt.ylabel('FPR')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=fpr_values_kraska, err_style="band",label = "Kraska",linewidth = 1.5,marker="o")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %% [markdown]
# # Projection model

# %%
class Projection_BloomFilter:
    def __init__(self, size, hash_count, dim):
        vectors = np.random.normal(0,1,size=(hash_count,dim)) #random vectors(each row) from normal distribution, not unit vectors
        i=0
        while(i<hash_count):
            if(vectors[i][0]<0):
                vectors[i][0] *= -1
               # print("initial v", vectors[i])
                #vectors[i]=np.random.normal(0,1,size=(1,dim))
                #print("changed v", vectors[i])
            i = i+1
       # print(vectors)        
        self.unit_vectors = np.transpose(vectors/np.sqrt(np.transpose([np.sum(np.multiply(vectors,vectors),1)]))) #Matrix where each column is a unit vector, used as hash
        self.size = size
        self.hash_count = hash_count
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)

    def give_hash_values(self,X):
        projections = np.dot(X,self.unit_vectors) #Projections of datapoints on unit vectors
        norm_proj = 1/(1+np.exp(-projections)) #Sigmoid on each value so that they are in the range (0,1)
        hash_values = (norm_proj*(self.size-1)).astype(int) #All values are integers in the range [0,size-1]
        return hash_values                        #Each row contains hash values of that datapoint

    def add(self,x):
        hash_values = self.give_hash_values(x)
        for i in hash_values:
            self.bit_array[i] = 1
        
    def bulk_add(self, X):
        hash_values = self.give_hash_values(X)
        for i in hash_values:
            for j in i:
                self.bit_array[j] = 1
            
    def lookup(self, x):
        hash_values = self.give_hash_values(x)
        for i in hash_values:
            if(self.bit_array[i]==0):
                return False
        return True

    
#(Input:bloom filter,normalized positive data,normalized negative data; Output:(-1) for false negative, otherwise fpr)
def find_fpr(bf,x_pos,x_neg):
    fp = 0
    tn = 0
    pos_hash_values = bf.give_hash_values(x_pos)
    neg_hash_values = bf.give_hash_values(x_neg)
    for i in pos_hash_values:
        for j in i:
            if(bf.bit_array[j]==0):
                return -1
    for i in neg_hash_values:
        flag = 0
        for j in i:
            if(bf.bit_array[j]==0):
                tn += 1 
                flag = 1           
                break
        if(flag==0):
            fp += 1
    return fp/(fp+tn)

def find_fpr2(bf,x_neg):
    fp = 0
    tn = 0
    neg_hash_values = bf.give_hash_values(x_neg)
    for i in neg_hash_values:
        flag = 0
        for j in i:
            if(bf.bit_array[j]==0):
                tn += 1 
                flag = 1           
                break
        if(flag==0):
            fp += 1
    return fp/(fp+tn)

# %%
def get_data_points_Projection(x_train,x_test,y_train,init_size,diff,num,epochs,fpr_values,size_values):
    input_dim = x_train.shape[1]
    n = sum(y_train)
    x_pos = x_train[(y_train==1).reshape(-1)]
    print(x_pos.shape)
    x_neg = x_train[(y_train==0).reshape(-1)]
    average_over = 5   # Increase to make the graph smoother
    for i in range(0,num):
        m = init_size + i*diff
        k = eff_k(m,n,1)
        fpr = 1
        tempbf = Projection_BloomFilter(m,k,input_dim)
        sum_fpr = 0
        for it in range(0,average_over):
            for j in range(0,epochs):
                bf = Projection_BloomFilter(m,k,input_dim)
                bf.bulk_add(x_pos)
                temp = find_fpr(bf,x_pos,x_neg)
                if(fpr>temp):
                    fpr = temp
                    tempbf=bf
            sum_fpr += find_fpr2(tempbf,x_test)
        fpr_test = sum_fpr/average_over
        print("Size: %d Bits - FPR: %f \n\n\n" % (m,fpr_test))
        fpr_values += [fpr_test]
        size_values += [m]

# %%
fpr_values = []
size_values = []

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (357, 30)
# Size: 5 Bits - FPR: 0.443396
#
#
#
# Size: 15 Bits - FPR: 0.311321
#
#
#
# Size: 25 Bits - FPR: 0.292453
#
#
#
# Size: 35 Bits - FPR: 0.303774
#
#
#
# Size: 45 Bits - FPR: 0.235849
#
#
#
# Size: 55 Bits - FPR: 0.262264
#
#
#
# Size: 65 Bits - FPR: 0.169811
#
#
#
# Size: 75 Bits - FPR: 0.320755
#
#
#
# Size: 85 Bits - FPR: 0.169811
#
#
#
# Size: 95 Bits - FPR: 0.339623
#
#
#
# Size: 105 Bits - FPR: 0.152830
#
#
#
# Size: 115 Bits - FPR: 0.098113
#
#
#
# Size: 125 Bits - FPR: 0.154717
#
#
#
# Size: 135 Bits - FPR: 0.111321
#
#
#
# Size: 145 Bits - FPR: 0.150943
#
#
#
# Size: 155 Bits - FPR: 0.196226
#
#
#
# Size: 165 Bits - FPR: 0.167925
#
#
#
# Size: 175 Bits - FPR: 0.128302
#
#
#
# Size: 185 Bits - FPR: 0.188679
#
#
#
# Size: 195 Bits - FPR: 0.132075
#
#
#
# Size: 205 Bits - FPR: 0.139623
#
#
#
# Size: 215 Bits - FPR: 0.066038
#
#
#
# Size: 225 Bits - FPR: 0.094340
#
#
#
# Size: 235 Bits - FPR: 0.222642
#
#
#
# Size: 245 Bits - FPR: 0.113208
#
#
#
# Size: 255 Bits - FPR: 0.162264
#
#
#
# Size: 265 Bits - FPR: 0.105660
#
#
#
# Size: 275 Bits - FPR: 0.100000
#
#
#
# Size: 285 Bits - FPR: 0.177358
#
#
#
# Size: 295 Bits - FPR: 0.207547
#
#
#
# Size: 305 Bits - FPR: 0.107547
#
#
#
# Size: 315 Bits - FPR: 0.141509
#
#
#
# Size: 325 Bits - FPR: 0.149057
#
#
#
# Size: 335 Bits - FPR: 0.120755
#
#
#
# Size: 345 Bits - FPR: 0.132075
#
#
#
# Size: 355 Bits - FPR: 0.071698
#
#
#
# Size: 365 Bits - FPR: 0.067925
#
#
#
# Size: 375 Bits - FPR: 0.075472
#
#
#
# Size: 385 Bits - FPR: 0.133962
#
#
#
# Size: 395 Bits - FPR: 0.094340
#
#
#
# Size: 405 Bits - FPR: 0.105660
#
#
#
# Size: 415 Bits - FPR: 0.113208
#
#
#
# Size: 425 Bits - FPR: 0.120755
#
#
#
# Size: 435 Bits - FPR: 0.118868
#
#
#
# Size: 445 Bits - FPR: 0.086792
#
#
#
# Size: 455 Bits - FPR: 0.066038
#
#
#
# Size: 465 Bits - FPR: 0.083019
#
#
#
# Size: 475 Bits - FPR: 0.062264
#
#
#
# Size: 485 Bits - FPR: 0.113208
#
#
#
# Size: 495 Bits - FPR: 0.107547
#
#
#
# Size: 505 Bits - FPR: 0.141509
#
#
#
# Size: 515 Bits - FPR: 0.056604
#
#
#
# Size: 525 Bits - FPR: 0.086792
#
#
#
# Size: 535 Bits - FPR: 0.092453
#
#
#
# Size: 545 Bits - FPR: 0.103774
#
#
#
# Size: 555 Bits - FPR: 0.077358
#
#
#
# Size: 565 Bits - FPR: 0.092453
#
#
#
# Size: 575 Bits - FPR: 0.090566
#
#
#
# Size: 585 Bits - FPR: 0.047170
#
#
#
# Size: 595 Bits - FPR: 0.064151
#
#
#
# Size: 605 Bits - FPR: 0.047170
#
#
#
# Size: 615 Bits - FPR: 0.098113
#
#
#
# Size: 625 Bits - FPR: 0.054717
#
#
#
# Size: 635 Bits - FPR: 0.100000
#
#
#
# Size: 645 Bits - FPR: 0.028302
#
#
#
# Size: 655 Bits - FPR: 0.096226
#
#
#
# Size: 665 Bits - FPR: 0.066038
#
#
#
# Size: 675 Bits - FPR: 0.060377
#
#
#
# Size: 685 Bits - FPR: 0.077358
#
#
#
# Size: 695 Bits - FPR: 0.133962
#
#
#
# Size: 705 Bits - FPR: 0.075472
#
#
#
# Size: 715 Bits - FPR: 0.060377
#
#
#
# Size: 725 Bits - FPR: 0.058491
#
#
#
# Size: 735 Bits - FPR: 0.047170
#
#
#
# Size: 745 Bits - FPR: 0.062264
#
#
#
# Size: 755 Bits - FPR: 0.150943
#
#
#
# Size: 765 Bits - FPR: 0.047170
#
#
#
# Size: 775 Bits - FPR: 0.067925
#
#
#
# Size: 785 Bits - FPR: 0.075472
#
#
#
# Size: 795 Bits - FPR: 0.084906
#
#
#
# Size: 805 Bits - FPR: 0.067925
#
#
#
# Size: 815 Bits - FPR: 0.060377
#
#
#
# Size: 825 Bits - FPR: 0.050943
#
#
#
# Size: 835 Bits - FPR: 0.079245
#
#
#
# Size: 845 Bits - FPR: 0.054717
#
#
#
# Size: 855 Bits - FPR: 0.035849
#
#
#
# Size: 865 Bits - FPR: 0.092453
#
#
#
# Size: 875 Bits - FPR: 0.086792
#
#
#
# Size: 885 Bits - FPR: 0.066038
#
#
#
# Size: 895 Bits - FPR: 0.077358
#
#
#
# Size: 905 Bits - FPR: 0.054717
#
#
#
# Size: 915 Bits - FPR: 0.067925
#
#
#
# Size: 925 Bits - FPR: 0.033962
#
#
#
# Size: 935 Bits - FPR: 0.039623
#
#
#
# Size: 945 Bits - FPR: 0.075472
#
#
#
# Size: 955 Bits - FPR: 0.020755
#
#
#
# Size: 965 Bits - FPR: 0.103774
#
#
#
# Size: 975 Bits - FPR: 0.056604
#
#
#
# Size: 985 Bits - FPR: 0.058491
#
#
#
# Size: 995 Bits - FPR: 0.043396
#
#
#
# Size: 1005 Bits - FPR: 0.054717
#
#
#
# Size: 1015 Bits - FPR: 0.045283
#
#
#
# Size: 1025 Bits - FPR: 0.028302
#
#
#
# Size: 1035 Bits - FPR: 0.037736
#
#
#
# Size: 1045 Bits - FPR: 0.047170
#
#
#
# Size: 1055 Bits - FPR: 0.037736
#
#
#
# Size: 1065 Bits - FPR: 0.067925
#
#
#
# Size: 1075 Bits - FPR: 0.079245
#
#
#
# Size: 1085 Bits - FPR: 0.041509
#
#
#
# Size: 1095 Bits - FPR: 0.033962
#
#
#
# Size: 1105 Bits - FPR: 0.033962
#
#
#
# Size: 1115 Bits - FPR: 0.028302
#
#
#
# Size: 1125 Bits - FPR: 0.064151
#
#
#
# Size: 1135 Bits - FPR: 0.094340
#
#
#
# Size: 1145 Bits - FPR: 0.009434
#
#
#
# Size: 1155 Bits - FPR: 0.022642
#
#
#
# Size: 1165 Bits - FPR: 0.088679
#
#
#
# Size: 1175 Bits - FPR: 0.022642
#
#
#
# Size: 1185 Bits - FPR: 0.050943
#
#
#
# Size: 1195 Bits - FPR: 0.066038
#
#
#
# Size: 1205 Bits - FPR: 0.071698
#
#
#
# Size: 1215 Bits - FPR: 0.032075
#
#
#
# Size: 1225 Bits - FPR: 0.028302
#
#
#
# Size: 1235 Bits - FPR: 0.043396
#
#
#
# Size: 1245 Bits - FPR: 0.086792
#
#
#
# Size: 1255 Bits - FPR: 0.037736
#
#
#
# Size: 1265 Bits - FPR: 0.041509
#
#
#
# Size: 1275 Bits - FPR: 0.032075
#
#
#
# Size: 1285 Bits - FPR: 0.026415
#
#
#
# Size: 1295 Bits - FPR: 0.032075
#
#
#
# Size: 1305 Bits - FPR: 0.047170
#
#
#
# Size: 1315 Bits - FPR: 0.056604
#
#
#
# Size: 1325 Bits - FPR: 0.050943
#
#
#
# Size: 1335 Bits - FPR: 0.056604
#
#
#
# Size: 1345 Bits - FPR: 0.052830
#
#
#
# Size: 1355 Bits - FPR: 0.054717
#
#
#
# Size: 1365 Bits - FPR: 0.037736
#
#
#
# Size: 1375 Bits - FPR: 0.018868
#
#
#
# Size: 1385 Bits - FPR: 0.084906
#
#
#
# Size: 1395 Bits - FPR: 0.067925
#
#
#
# Size: 1405 Bits - FPR: 0.041509
#
#
#
# Size: 1415 Bits - FPR: 0.028302
#
#
#
# Size: 1425 Bits - FPR: 0.050943
#
#
#
# Size: 1435 Bits - FPR: 0.009434
#
#
#
# Size: 1445 Bits - FPR: 0.037736
#
#
#
# Size: 1455 Bits - FPR: 0.033962
#
#
#
# Size: 1465 Bits - FPR: 0.062264
#
#
#
# Size: 1475 Bits - FPR: 0.028302
#
#
#
# Size: 1485 Bits - FPR: 0.037736
#
#
#
# Size: 1495 Bits - FPR: 0.030189
#
#
#
# Size: 1505 Bits - FPR: 0.067925
#
#
#
# Size: 1515 Bits - FPR: 0.045283
#
#
#
# Size: 1525 Bits - FPR: 0.024528
#
#
#
# Size: 1535 Bits - FPR: 0.066038
#
#
#
# Size: 1545 Bits - FPR: 0.049057
#
#
#
# Size: 1555 Bits - FPR: 0.030189
#
#
#
# Size: 1565 Bits - FPR: 0.039623
#
#
#
# Size: 1575 Bits - FPR: 0.013208
#
#
#
# Size: 1585 Bits - FPR: 0.022642
#
#
#
# Size: 1595 Bits - FPR: 0.047170
#
#
#
# Size: 1605 Bits - FPR: 0.028302
#
#
#
# Size: 1615 Bits - FPR: 0.018868
#
#
#
# Size: 1625 Bits - FPR: 0.033962
#
#
#
# Size: 1635 Bits - FPR: 0.037736
#
#
#
# Size: 1645 Bits - FPR: 0.030189
#
#
#
# Size: 1655 Bits - FPR: 0.018868
#
#
#
# Size: 1665 Bits - FPR: 0.067925
#
#
#
# Size: 1675 Bits - FPR: 0.015094
#
#
#
# Size: 1685 Bits - FPR: 0.015094
#
#
#
# Size: 1695 Bits - FPR: 0.032075
#
#
#
# Size: 1705 Bits - FPR: 0.037736
#
#
#
# Size: 1715 Bits - FPR: 0.020755
#
#
#
# Size: 1725 Bits - FPR: 0.037736
#
#
#
# Size: 1735 Bits - FPR: 0.015094
#
#
#
# Size: 1745 Bits - FPR: 0.043396
#
#
#
# Size: 1755 Bits - FPR: 0.043396
#
#
#
# Size: 1765 Bits - FPR: 0.024528
#
#
#
# Size: 1775 Bits - FPR: 0.022642
#
#
#
# Size: 1785 Bits - FPR: 0.009434
#
#
#
# Size: 1795 Bits - FPR: 0.011321
#
#
#
# Size: 1805 Bits - FPR: 0.016981
#
#
#
# Size: 1815 Bits - FPR: 0.028302
#
#
#
# Size: 1825 Bits - FPR: 0.037736
#
#
#
# Size: 1835 Bits - FPR: 0.009434
#
#
#
# Size: 1845 Bits - FPR: 0.052830
#
#
#
# Size: 1855 Bits - FPR: 0.009434
#
#
#
# Size: 1865 Bits - FPR: 0.035849
#
#
#
# Size: 1875 Bits - FPR: 0.105660
#
#
#
# Size: 1885 Bits - FPR: 0.066038
#
#
#
# Size: 1895 Bits - FPR: 0.028302
#
#
#
# Size: 1905 Bits - FPR: 0.064151
#
#
#
# Size: 1915 Bits - FPR: 0.030189
#
#
#
# Size: 1925 Bits - FPR: 0.003774
#
#
#
# Size: 1935 Bits - FPR: 0.033962
#
#
#
# Size: 1945 Bits - FPR: 0.037736
#
#
#
# Size: 1955 Bits - FPR: 0.026415
#
#
#
# Size: 1965 Bits - FPR: 0.016981
#
#
#
# Size: 1975 Bits - FPR: 0.018868
#
#
#
# Size: 1985 Bits - FPR: 0.033962
#
#
#
# Size: 1995 Bits - FPR: 0.030189

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (357, 30)
# Size: 5 Bits - FPR: 0.435849
#
#
#
# Size: 15 Bits - FPR: 0.301887
#
#
#
# Size: 25 Bits - FPR: 0.386792
#
#
#
# Size: 35 Bits - FPR: 0.196226
#
#
#
# Size: 45 Bits - FPR: 0.296226
#
#
#
# Size: 55 Bits - FPR: 0.233962
#
#
#
# Size: 65 Bits - FPR: 0.160377
#
#
#
# Size: 75 Bits - FPR: 0.273585
#
#
#
# Size: 85 Bits - FPR: 0.245283
#
#
#
# Size: 95 Bits - FPR: 0.183019
#
#
#
# Size: 105 Bits - FPR: 0.235849
#
#
#
# Size: 115 Bits - FPR: 0.239623
#
#
#
# Size: 125 Bits - FPR: 0.149057
#
#
#
# Size: 135 Bits - FPR: 0.226415
#
#
#
# Size: 145 Bits - FPR: 0.154717
#
#
#
# Size: 155 Bits - FPR: 0.128302
#
#
#
# Size: 165 Bits - FPR: 0.084906
#
#
#
# Size: 175 Bits - FPR: 0.132075
#
#
#
# Size: 185 Bits - FPR: 0.211321
#
#
#
# Size: 195 Bits - FPR: 0.158491
#
#
#
# Size: 205 Bits - FPR: 0.162264
#
#
#
# Size: 215 Bits - FPR: 0.084906
#
#
#
# Size: 225 Bits - FPR: 0.094340
#
#
#
# Size: 235 Bits - FPR: 0.130189
#
#
#
# Size: 245 Bits - FPR: 0.173585
#
#
#
# Size: 255 Bits - FPR: 0.133962
#
#
#
# Size: 265 Bits - FPR: 0.124528
#
#
#
# Size: 275 Bits - FPR: 0.118868
#
#
#
# Size: 285 Bits - FPR: 0.037736
#
#
#
# Size: 295 Bits - FPR: 0.147170
#
#
#
# Size: 305 Bits - FPR: 0.147170
#
#
#
# Size: 315 Bits - FPR: 0.133962
#
#
#
# Size: 325 Bits - FPR: 0.098113
#
#
#
# Size: 335 Bits - FPR: 0.145283
#
#
#
# Size: 345 Bits - FPR: 0.132075
#
#
#
# Size: 355 Bits - FPR: 0.171698
#
#
#
# Size: 365 Bits - FPR: 0.158491
#
#
#
# Size: 375 Bits - FPR: 0.139623
#
#
#
# Size: 385 Bits - FPR: 0.103774
#
#
#
# Size: 395 Bits - FPR: 0.047170
#
#
#
# Size: 405 Bits - FPR: 0.100000
#
#
#
# Size: 415 Bits - FPR: 0.113208
#
#
#
# Size: 425 Bits - FPR: 0.160377
#
#
#
# Size: 435 Bits - FPR: 0.100000
#
#
#
# Size: 445 Bits - FPR: 0.162264
#
#
#
# Size: 455 Bits - FPR: 0.132075
#
#
#
# Size: 465 Bits - FPR: 0.130189
#
#
#
# Size: 475 Bits - FPR: 0.075472
#
#
#
# Size: 485 Bits - FPR: 0.116981
#
#
#
# Size: 495 Bits - FPR: 0.062264
#
#
#
# Size: 505 Bits - FPR: 0.143396
#
#
#
# Size: 515 Bits - FPR: 0.075472
#
#
#
# Size: 525 Bits - FPR: 0.056604
#
#
#
# Size: 535 Bits - FPR: 0.101887
#
#
#
# Size: 545 Bits - FPR: 0.101887
#
#
#
# Size: 555 Bits - FPR: 0.130189
#
#
#
# Size: 565 Bits - FPR: 0.141509
#
#
#
# Size: 575 Bits - FPR: 0.077358
#
#
#
# Size: 585 Bits - FPR: 0.088679
#
#
#
# Size: 595 Bits - FPR: 0.113208
#
#
#
# Size: 605 Bits - FPR: 0.058491
#
#
#
# Size: 615 Bits - FPR: 0.086792
#
#
#
# Size: 625 Bits - FPR: 0.075472
#
#
#
# Size: 635 Bits - FPR: 0.060377
#
#
#
# Size: 645 Bits - FPR: 0.113208
#
#
#
# Size: 655 Bits - FPR: 0.073585
#
#
#
# Size: 665 Bits - FPR: 0.109434
#
#
#
# Size: 675 Bits - FPR: 0.066038
#
#
#
# Size: 685 Bits - FPR: 0.088679
#
#
#
# Size: 695 Bits - FPR: 0.067925
#
#
#
# Size: 705 Bits - FPR: 0.066038
#
#
#
# Size: 715 Bits - FPR: 0.084906
#
#
#
# Size: 725 Bits - FPR: 0.098113
#
#
#
# Size: 735 Bits - FPR: 0.128302
#
#
#
# Size: 745 Bits - FPR: 0.047170
#
#
#
# Size: 755 Bits - FPR: 0.058491
#
#
#
# Size: 765 Bits - FPR: 0.037736
#
#
#
# Size: 775 Bits - FPR: 0.052830
#
#
#
# Size: 785 Bits - FPR: 0.079245
#
#
#
# Size: 795 Bits - FPR: 0.092453
#
#
#
# Size: 805 Bits - FPR: 0.050943
#
#
#
# Size: 815 Bits - FPR: 0.092453
#
#
#
# Size: 825 Bits - FPR: 0.050943
#
#
#
# Size: 835 Bits - FPR: 0.052830
#
#
#
# Size: 845 Bits - FPR: 0.039623
#
#
#
# Size: 855 Bits - FPR: 0.073585
#
#
#
# Size: 865 Bits - FPR: 0.103774
#
#
#
# Size: 875 Bits - FPR: 0.075472
#
#
#
# Size: 885 Bits - FPR: 0.056604
#
#
#
# Size: 895 Bits - FPR: 0.062264
#
#
#
# Size: 905 Bits - FPR: 0.058491
#
#
#
# Size: 915 Bits - FPR: 0.056604
#
#
#
# Size: 925 Bits - FPR: 0.064151
#
#
#
# Size: 935 Bits - FPR: 0.083019
#
#
#
# Size: 945 Bits - FPR: 0.047170
#
#
#
# Size: 955 Bits - FPR: 0.094340
#
#
#
# Size: 965 Bits - FPR: 0.052830
#
#
#
# Size: 975 Bits - FPR: 0.047170
#
#
#
# Size: 985 Bits - FPR: 0.050943
#
#
#
# Size: 995 Bits - FPR: 0.056604
#
#
#
# Size: 1005 Bits - FPR: 0.047170
#
#
#
# Size: 1015 Bits - FPR: 0.118868
#
#
#
# Size: 1025 Bits - FPR: 0.069811
#
#
#
# Size: 1035 Bits - FPR: 0.067925
#
#
#
# Size: 1045 Bits - FPR: 0.033962
#
#
#
# Size: 1055 Bits - FPR: 0.086792
#
#
#
# Size: 1065 Bits - FPR: 0.047170
#
#
#
# Size: 1075 Bits - FPR: 0.075472
#
#
#
# Size: 1085 Bits - FPR: 0.103774
#
#
#
# Size: 1095 Bits - FPR: 0.081132
#
#
#
# Size: 1105 Bits - FPR: 0.035849
#
#
#
# Size: 1115 Bits - FPR: 0.037736
#
#
#
# Size: 1125 Bits - FPR: 0.058491
#
#
#
# Size: 1135 Bits - FPR: 0.056604
#
#
#
# Size: 1145 Bits - FPR: 0.037736
#
#
#
# Size: 1155 Bits - FPR: 0.041509
#
#
#
# Size: 1165 Bits - FPR: 0.024528
#
#
#
# Size: 1175 Bits - FPR: 0.071698
#
#
#
# Size: 1185 Bits - FPR: 0.024528
#
#
#
# Size: 1195 Bits - FPR: 0.030189
#
#
#
# Size: 1205 Bits - FPR: 0.032075
#
#
#
# Size: 1215 Bits - FPR: 0.047170
#
#
#
# Size: 1225 Bits - FPR: 0.049057
#
#
#
# Size: 1235 Bits - FPR: 0.049057
#
#
#
# Size: 1245 Bits - FPR: 0.056604
#
#
#
# Size: 1255 Bits - FPR: 0.039623
#
#
#
# Size: 1265 Bits - FPR: 0.066038
#
#
#
# Size: 1275 Bits - FPR: 0.030189
#
#
#
# Size: 1285 Bits - FPR: 0.056604
#
#
#
# Size: 1295 Bits - FPR: 0.037736
#
#
#
# Size: 1305 Bits - FPR: 0.037736
#
#
#
# Size: 1315 Bits - FPR: 0.032075
#
#
#
# Size: 1325 Bits - FPR: 0.056604
#
#
#
# Size: 1335 Bits - FPR: 0.103774
#
#
#
# Size: 1345 Bits - FPR: 0.056604
#
#
#
# Size: 1355 Bits - FPR: 0.043396
#
#
#
# Size: 1365 Bits - FPR: 0.009434
#
#
#
# Size: 1375 Bits - FPR: 0.018868
#
#
#
# Size: 1385 Bits - FPR: 0.066038
#
#
#
# Size: 1395 Bits - FPR: 0.058491
#
#
#
# Size: 1405 Bits - FPR: 0.018868
#
#
#
# Size: 1415 Bits - FPR: 0.039623
#
#
#
# Size: 1425 Bits - FPR: 0.022642
#
#
#
# Size: 1435 Bits - FPR: 0.073585
#
#
#
# Size: 1445 Bits - FPR: 0.037736
#
#
#
# Size: 1455 Bits - FPR: 0.075472
#
#
#
# Size: 1465 Bits - FPR: 0.024528
#
#
#
# Size: 1475 Bits - FPR: 0.024528
#
#
#
# Size: 1485 Bits - FPR: 0.028302
#
#
#
# Size: 1495 Bits - FPR: 0.041509
#
#
#
# Size: 1505 Bits - FPR: 0.037736
#
#
#
# Size: 1515 Bits - FPR: 0.037736
#
#
#
# Size: 1525 Bits - FPR: 0.054717
#
#
#
# Size: 1535 Bits - FPR: 0.016981
#
#
#
# Size: 1545 Bits - FPR: 0.024528
#
#
#
# Size: 1555 Bits - FPR: 0.039623
#
#
#
# Size: 1565 Bits - FPR: 0.066038
#
#
#
# Size: 1575 Bits - FPR: 0.032075
#
#
#
# Size: 1585 Bits - FPR: 0.018868
#
#
#
# Size: 1595 Bits - FPR: 0.035849
#
#
#
# Size: 1605 Bits - FPR: 0.000000
#
#
#
# Size: 1615 Bits - FPR: 0.026415
#
#
#
# Size: 1625 Bits - FPR: 0.028302
#
#
#
# Size: 1635 Bits - FPR: 0.069811
#
#
#
# Size: 1645 Bits - FPR: 0.005660
#
#
#
# Size: 1655 Bits - FPR: 0.009434
#
#
#
# Size: 1665 Bits - FPR: 0.047170
#
#
#
# Size: 1675 Bits - FPR: 0.028302
#
#
#
# Size: 1685 Bits - FPR: 0.026415
#
#
#
# Size: 1695 Bits - FPR: 0.056604
#
#
#
# Size: 1705 Bits - FPR: 0.037736
#
#
#
# Size: 1715 Bits - FPR: 0.062264
#
#
#
# Size: 1725 Bits - FPR: 0.020755
#
#
#
# Size: 1735 Bits - FPR: 0.050943
#
#
#
# Size: 1745 Bits - FPR: 0.043396
#
#
#
# Size: 1755 Bits - FPR: 0.077358
#
#
#
# Size: 1765 Bits - FPR: 0.028302
#
#
#
# Size: 1775 Bits - FPR: 0.024528
#
#
#
# Size: 1785 Bits - FPR: 0.035849
#
#
#
# Size: 1795 Bits - FPR: 0.026415
#
#
#
# Size: 1805 Bits - FPR: 0.028302
#
#
#
# Size: 1815 Bits - FPR: 0.037736
#
#
#
# Size: 1825 Bits - FPR: 0.026415
#
#
#
# Size: 1835 Bits - FPR: 0.037736
#
#
#
# Size: 1845 Bits - FPR: 0.032075
#
#
#
# Size: 1855 Bits - FPR: 0.028302
#
#
#
# Size: 1865 Bits - FPR: 0.018868
#
#
#
# Size: 1875 Bits - FPR: 0.039623
#
#
#
# Size: 1885 Bits - FPR: 0.028302
#
#
#
# Size: 1895 Bits - FPR: 0.039623
#
#
#
# Size: 1905 Bits - FPR: 0.028302
#
#
#
# Size: 1915 Bits - FPR: 0.037736
#
#
#
# Size: 1925 Bits - FPR: 0.060377
#
#
#
# Size: 1935 Bits - FPR: 0.090566
#
#
#
# Size: 1945 Bits - FPR: 0.039623
#
#
#
# Size: 1955 Bits - FPR: 0.047170
#
#
#
# Size: 1965 Bits - FPR: 0.018868
#
#
#
# Size: 1975 Bits - FPR: 0.056604
#
#
#
# Size: 1985 Bits - FPR: 0.047170
#
#
#
# Size: 1995 Bits - FPR: 0.013208

# %%
get_data_points_Projection(x_train,x_test,y_train,5,10,200,100,fpr_values,size_values)
# Out:
# (357, 30)
# Size: 5 Bits - FPR: 0.415094
#
#
#
# Size: 15 Bits - FPR: 0.462264
#
#
#
# Size: 25 Bits - FPR: 0.254717
#
#
#
# Size: 35 Bits - FPR: 0.237736
#
#
#
# Size: 45 Bits - FPR: 0.188679
#
#
#
# Size: 55 Bits - FPR: 0.179245
#
#
#
# Size: 65 Bits - FPR: 0.258491
#
#
#
# Size: 75 Bits - FPR: 0.279245
#
#
#
# Size: 85 Bits - FPR: 0.311321
#
#
#
# Size: 95 Bits - FPR: 0.194340
#
#
#
# Size: 105 Bits - FPR: 0.141509
#
#
#
# Size: 115 Bits - FPR: 0.113208
#
#
#
# Size: 125 Bits - FPR: 0.232075
#
#
#
# Size: 135 Bits - FPR: 0.141509
#
#
#
# Size: 145 Bits - FPR: 0.164151
#
#
#
# Size: 155 Bits - FPR: 0.215094
#
#
#
# Size: 165 Bits - FPR: 0.147170
#
#
#
# Size: 175 Bits - FPR: 0.194340
#
#
#
# Size: 185 Bits - FPR: 0.122642
#
#
#
# Size: 195 Bits - FPR: 0.147170
#
#
#
# Size: 205 Bits - FPR: 0.141509
#
#
#
# Size: 215 Bits - FPR: 0.171698
#
#
#
# Size: 225 Bits - FPR: 0.200000
#
#
#
# Size: 235 Bits - FPR: 0.135849
#
#
#
# Size: 245 Bits - FPR: 0.211321
#
#
#
# Size: 255 Bits - FPR: 0.122642
#
#
#
# Size: 265 Bits - FPR: 0.090566
#
#
#
# Size: 275 Bits - FPR: 0.107547
#
#
#
# Size: 285 Bits - FPR: 0.077358
#
#
#
# Size: 295 Bits - FPR: 0.105660
#
#
#
# Size: 305 Bits - FPR: 0.188679
#
#
#
# Size: 315 Bits - FPR: 0.079245
#
#
#
# Size: 325 Bits - FPR: 0.103774
#
#
#
# Size: 335 Bits - FPR: 0.122642
#
#
#
# Size: 345 Bits - FPR: 0.094340
#
#
#
# Size: 355 Bits - FPR: 0.132075
#
#
#
# Size: 365 Bits - FPR: 0.092453
#
#
#
# Size: 375 Bits - FPR: 0.132075
#
#
#
# Size: 385 Bits - FPR: 0.073585
#
#
#
# Size: 395 Bits - FPR: 0.066038
#
#
#
# Size: 405 Bits - FPR: 0.081132
#
#
#
# Size: 415 Bits - FPR: 0.073585
#
#
#
# Size: 425 Bits - FPR: 0.118868
#
#
#
# Size: 435 Bits - FPR: 0.094340
#
#
#
# Size: 445 Bits - FPR: 0.100000
#
#
#
# Size: 455 Bits - FPR: 0.069811
#
#
#
# Size: 465 Bits - FPR: 0.141509
#
#
#
# Size: 475 Bits - FPR: 0.084906
#
#
#
# Size: 485 Bits - FPR: 0.109434
#
#
#
# Size: 495 Bits - FPR: 0.098113
#
#
#
# Size: 505 Bits - FPR: 0.084906
#
#
#
# Size: 515 Bits - FPR: 0.100000
#
#
#
# Size: 525 Bits - FPR: 0.116981
#
#
#
# Size: 535 Bits - FPR: 0.037736
#
#
#
# Size: 545 Bits - FPR: 0.103774
#
#
#
# Size: 555 Bits - FPR: 0.132075
#
#
#
# Size: 565 Bits - FPR: 0.081132
#
#
#
# Size: 575 Bits - FPR: 0.067925
#
#
#
# Size: 585 Bits - FPR: 0.128302
#
#
#
# Size: 595 Bits - FPR: 0.075472
#
#
#
# Size: 605 Bits - FPR: 0.094340
#
#
#
# Size: 615 Bits - FPR: 0.037736
#
#
#
# Size: 625 Bits - FPR: 0.096226
#
#
#
# Size: 635 Bits - FPR: 0.056604
#
#
#
# Size: 645 Bits - FPR: 0.054717
#
#
#
# Size: 655 Bits - FPR: 0.113208
#
#
#
# Size: 665 Bits - FPR: 0.058491
#
#
#
# Size: 675 Bits - FPR: 0.064151
#
#
#
# Size: 685 Bits - FPR: 0.056604
#
#
#
# Size: 695 Bits - FPR: 0.098113
#
#
#
# Size: 705 Bits - FPR: 0.041509
#
#
#
# Size: 715 Bits - FPR: 0.090566
#
#
#
# Size: 725 Bits - FPR: 0.160377
#
#
#
# Size: 735 Bits - FPR: 0.096226
#
#
#
# Size: 745 Bits - FPR: 0.056604
#
#
#
# Size: 755 Bits - FPR: 0.060377
#
#
#
# Size: 765 Bits - FPR: 0.050943
#
#
#
# Size: 775 Bits - FPR: 0.060377
#
#
#
# Size: 785 Bits - FPR: 0.109434
#
#
#
# Size: 795 Bits - FPR: 0.047170
#
#
#
# Size: 805 Bits - FPR: 0.060377
#
#
#
# Size: 815 Bits - FPR: 0.079245
#
#
#
# Size: 825 Bits - FPR: 0.058491
#
#
#
# Size: 835 Bits - FPR: 0.079245
#
#
#
# Size: 845 Bits - FPR: 0.043396
#
#
#
# Size: 855 Bits - FPR: 0.088679
#
#
#
# Size: 865 Bits - FPR: 0.043396
#
#
#
# Size: 875 Bits - FPR: 0.052830
#
#
#
# Size: 885 Bits - FPR: 0.050943
#
#
#
# Size: 895 Bits - FPR: 0.049057
#
#
#
# Size: 905 Bits - FPR: 0.052830
#
#
#
# Size: 915 Bits - FPR: 0.100000
#
#
#
# Size: 925 Bits - FPR: 0.073585
#
#
#
# Size: 935 Bits - FPR: 0.039623
#
#
#
# Size: 945 Bits - FPR: 0.066038
#
#
#
# Size: 955 Bits - FPR: 0.028302
#
#
#
# Size: 965 Bits - FPR: 0.075472
#
#
#
# Size: 975 Bits - FPR: 0.060377
#
#
#
# Size: 985 Bits - FPR: 0.077358
#
#
#
# Size: 995 Bits - FPR: 0.050943
#
#
#
# Size: 1005 Bits - FPR: 0.150943
#
#
#
# Size: 1015 Bits - FPR: 0.028302
#
#
#
# Size: 1025 Bits - FPR: 0.049057
#
#
#
# Size: 1035 Bits - FPR: 0.028302
#
#
#
# Size: 1045 Bits - FPR: 0.077358
#
#
#
# Size: 1055 Bits - FPR: 0.039623
#
#
#
# Size: 1065 Bits - FPR: 0.049057
#
#
#
# Size: 1075 Bits - FPR: 0.039623
#
#
#
# Size: 1085 Bits - FPR: 0.066038
#
#
#
# Size: 1095 Bits - FPR: 0.049057
#
#
#
# Size: 1105 Bits - FPR: 0.022642
#
#
#
# Size: 1115 Bits - FPR: 0.150943
#
#
#
# Size: 1125 Bits - FPR: 0.088679
#
#
#
# Size: 1135 Bits - FPR: 0.056604
#
#
#
# Size: 1145 Bits - FPR: 0.028302
#
#
#
# Size: 1155 Bits - FPR: 0.028302
#
#
#
# Size: 1165 Bits - FPR: 0.039623
#
#
#
# Size: 1175 Bits - FPR: 0.056604
#
#
#
# Size: 1185 Bits - FPR: 0.069811
#
#
#
# Size: 1195 Bits - FPR: 0.024528
#
#
#
# Size: 1205 Bits - FPR: 0.037736
#
#
#
# Size: 1215 Bits - FPR: 0.075472
#
#
#
# Size: 1225 Bits - FPR: 0.062264
#
#
#
# Size: 1235 Bits - FPR: 0.050943
#
#
#
# Size: 1245 Bits - FPR: 0.035849
#
#
#
# Size: 1255 Bits - FPR: 0.056604
#
#
#
# Size: 1265 Bits - FPR: 0.052830
#
#
#
# Size: 1275 Bits - FPR: 0.047170
#
#
#
# Size: 1285 Bits - FPR: 0.047170
#
#
#
# Size: 1295 Bits - FPR: 0.081132
#
#
#
# Size: 1305 Bits - FPR: 0.037736
#
#
#
# Size: 1315 Bits - FPR: 0.043396
#
#
#
# Size: 1325 Bits - FPR: 0.062264
#
#
#
# Size: 1335 Bits - FPR: 0.067925
#
#
#
# Size: 1345 Bits - FPR: 0.028302
#
#
#
# Size: 1355 Bits - FPR: 0.062264
#
#
#
# Size: 1365 Bits - FPR: 0.056604
#
#
#
# Size: 1375 Bits - FPR: 0.009434
#
#
#
# Size: 1385 Bits - FPR: 0.049057
#
#
#
# Size: 1395 Bits - FPR: 0.056604
#
#
#
# Size: 1405 Bits - FPR: 0.022642
#
#
#
# Size: 1415 Bits - FPR: 0.026415
#
#
#
# Size: 1425 Bits - FPR: 0.056604
#
#
#
# Size: 1435 Bits - FPR: 0.028302
#
#
#
# Size: 1445 Bits - FPR: 0.064151
#
#
#
# Size: 1455 Bits - FPR: 0.016981
#
#
#
# Size: 1465 Bits - FPR: 0.050943
#
#
#
# Size: 1475 Bits - FPR: 0.066038
#
#
#
# Size: 1485 Bits - FPR: 0.037736
#
#
#
# Size: 1495 Bits - FPR: 0.028302
#
#
#
# Size: 1505 Bits - FPR: 0.028302
#
#
#
# Size: 1515 Bits - FPR: 0.000000
#
#
#
# Size: 1525 Bits - FPR: 0.060377
#
#
#
# Size: 1535 Bits - FPR: 0.028302
#
#
#
# Size: 1545 Bits - FPR: 0.013208
#
#
#
# Size: 1555 Bits - FPR: 0.043396
#
#
#
# Size: 1565 Bits - FPR: 0.047170
#
#
#
# Size: 1575 Bits - FPR: 0.043396
#
#
#
# Size: 1585 Bits - FPR: 0.028302
#
#
#
# Size: 1595 Bits - FPR: 0.026415
#
#
#
# Size: 1605 Bits - FPR: 0.009434
#
#
#
# Size: 1615 Bits - FPR: 0.056604
#
#
#
# Size: 1625 Bits - FPR: 0.028302
#
#
#
# Size: 1635 Bits - FPR: 0.022642
#
#
#
# Size: 1645 Bits - FPR: 0.028302
#
#
#
# Size: 1655 Bits - FPR: 0.047170
#
#
#
# Size: 1665 Bits - FPR: 0.039623
#
#
#
# Size: 1675 Bits - FPR: 0.024528
#
#
#
# Size: 1685 Bits - FPR: 0.037736
#
#
#
# Size: 1695 Bits - FPR: 0.016981
#
#
#
# Size: 1705 Bits - FPR: 0.049057
#
#
#
# Size: 1715 Bits - FPR: 0.020755
#
#
#
# Size: 1725 Bits - FPR: 0.024528
#
#
#
# Size: 1735 Bits - FPR: 0.050943
#
#
#
# Size: 1745 Bits - FPR: 0.047170
#
#
#
# Size: 1755 Bits - FPR: 0.028302
#
#
#
# Size: 1765 Bits - FPR: 0.020755
#
#
#
# Size: 1775 Bits - FPR: 0.028302
#
#
#
# Size: 1785 Bits - FPR: 0.037736
#
#
#
# Size: 1795 Bits - FPR: 0.041509
#
#
#
# Size: 1805 Bits - FPR: 0.035849
#
#
#
# Size: 1815 Bits - FPR: 0.022642
#
#
#
# Size: 1825 Bits - FPR: 0.049057
#
#
#
# Size: 1835 Bits - FPR: 0.009434
#
#
#
# Size: 1845 Bits - FPR: 0.066038
#
#
#
# Size: 1855 Bits - FPR: 0.054717
#
#
#
# Size: 1865 Bits - FPR: 0.037736
#
#
#
# Size: 1875 Bits - FPR: 0.037736
#
#
#
# Size: 1885 Bits - FPR: 0.081132
#
#
#
# Size: 1895 Bits - FPR: 0.024528
#
#
#
# Size: 1905 Bits - FPR: 0.032075
#
#
#
# Size: 1915 Bits - FPR: 0.054717
#
#
#
# Size: 1925 Bits - FPR: 0.035849
#
#
#
# Size: 1935 Bits - FPR: 0.054717
#
#
#
# Size: 1945 Bits - FPR: 0.016981
#
#
#
# Size: 1955 Bits - FPR: 0.049057
#
#
#
# Size: 1965 Bits - FPR: 0.015094
#
#
#
# Size: 1975 Bits - FPR: 0.037736
#
#
#
# Size: 1985 Bits - FPR: 0.016981
#
#
#
# Size: 1995 Bits - FPR: 0.066038

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=fpr_values, err_style="band",label = "Projection",linewidth = 1.5,color="g")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
plt.plot(size_values,fpr_values)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()

# %% [markdown]
# # Normal Bloom Filter Values

# %%
def ideal_fpr(m,n):
    k = eff_k(m,n,1)
    return (1-(1-(1/m))**(n*k))**k

# %%
print(sum(y_train))
print(len(y_train))
# Out:
# [357]
# 463

# %%
n = sum(y_train)
y_ideal=[]
for x in size_values:
    y_ideal+=[float(ideal_fpr(x,n))]
print(len(y_ideal))
print(n)
# Out:
# 600
# [357]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=y_ideal, err_style="band",label = "Ideal",linewidth = 1.5,color="r")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
plt.plot(size_values,y_ideal)
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()

# %% [markdown]
# # FPR Comparison between Projection Model and Normal Bloom Filter

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values, y=fpr_values, err_style="band",label = "Projection",linewidth = 1.5,color="g")
sns.lineplot(x=size_values, y=y_ideal, err_style="band",label = "Ideal",linewidth = 1.5,color="r")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model

# %% [markdown]
# #  FPR Comparison between Kraska Hash Model, Projection Model and Normal Bloom Filter

# %%
plt.plot(size_values,y_ideal,color='red')
plt.plot(size_values,fpr_values,color='green')
plt.plot(size_values_kraska,fpr_values_kraska,color='blue')
plt.title('FPRs')
plt.xlabel('Size(in Bits)')
plt.ylabel('FPR')
plt.show()
# Red- Normal Bloom Filter
# Green- Projection Model
# Blue- Kraska Hash Model

# %% [markdown]
# # Size comparisons

# %%
fpr_values_projection = []

# %%
def get_data_points_Projection2(x_train,x_test,y_train,epochs,fpr_values,size_values_kraska):
    input_dim = x_train.shape[1]
    n = sum(y_train)
    x_pos = x_train[(y_train==1).reshape(-1)]
    print(x_pos.shape)
    x_neg = x_train[(y_train==0).reshape(-1)]
    average_over = 5   # Increase to make the graph smoother
    for i in size_values_kraska:
        m = i
        k = eff_k(m,n,1)
        fpr = 1
        tempbf = Projection_BloomFilter(m,k,input_dim)   
        sum_fpr = 0
        for it in range(0,average_over):
            for j in range(0,epochs):
                bf = Projection_BloomFilter(m,k,input_dim)
                bf.bulk_add(x_pos)
                temp = find_fpr(bf,x_pos,x_neg)
                if(fpr>temp):
                    fpr = temp
                    tempbf=bf
            sum_fpr += find_fpr2(tempbf,x_test)
        fpr_test = sum_fpr/average_over
        print("Size: %d Bits - FPR: %f \n\n\n" % (m,fpr_test))
        fpr_values += [fpr_test]

# %%
get_data_points_Projection2(x_train,x_test,y_train,100,fpr_values_projection,size_values_kraska)
# Out:
# (357, 30)
# Size: 2113 Bits - FPR: 0.037736
#
#
#
# Size: 4161 Bits - FPR: 0.009434
#
#
#
# Size: 6209 Bits - FPR: 0.028302
#
#
#
# Size: 8257 Bits - FPR: 0.000000
#
#
#
# Size: 10305 Bits - FPR: 0.000000
#
#
#
# Size: 12353 Bits - FPR: 0.000000
#
#
#
# Size: 14401 Bits - FPR: 0.000000
#
#
#
# Size: 16449 Bits - FPR: 0.000000
#
#
#
# Size: 18497 Bits - FPR: 0.000000
#
#
#
# Size: 20545 Bits - FPR: 0.000000
#
#
#
# Size: 22593 Bits - FPR: 0.000000
#
#
#
# Size: 24641 Bits - FPR: 0.000000
#
#
#
# Size: 26689 Bits - FPR: 0.000000
#
#
#
# Size: 28737 Bits - FPR: 0.000000
#
#
#
# Size: 30785 Bits - FPR: 0.000000
#
#
#
# Size: 32833 Bits - FPR: 0.000000
#
#
#
# Size: 34881 Bits - FPR: 0.000000
#
#
#
# Size: 36929 Bits - FPR: 0.000000
#
#
#
# Size: 38977 Bits - FPR: 0.000000
#
#
#
# Size: 41025 Bits - FPR: 0.000000
#
#
#
# Size: 2113 Bits - FPR: 0.043396
#
#
#
# Size: 4161 Bits - FPR: 0.000000
#
#
#
# Size: 6209 Bits - FPR: 0.000000
#
#
#
# Size: 8257 Bits - FPR: 0.009434
#
#
#
# Size: 10305 Bits - FPR: 0.000000
#
#
#
# Size: 12353 Bits - FPR: 0.000000
#
#
#
# Size: 14401 Bits - FPR: 0.000000
#
#
#
# Size: 16449 Bits - FPR: 0.000000
#
#
#
# Size: 18497 Bits - FPR: 0.000000
#
#
#
# Size: 20545 Bits - FPR: 0.000000
#
#
#
# Size: 22593 Bits - FPR: 0.000000
#
#
#
# Size: 24641 Bits - FPR: 0.000000
#
#
#
# Size: 26689 Bits - FPR: 0.000000
#
#
#
# Size: 28737 Bits - FPR: 0.000000
#
#
#
# Size: 30785 Bits - FPR: 0.000000
#
#
#
# Size: 32833 Bits - FPR: 0.000000
#
#
#
# Size: 34881 Bits - FPR: 0.000000
#
#
#
# Size: 36929 Bits - FPR: 0.000000
#
#
#
# Size: 38977 Bits - FPR: 0.000000
#
#
#
# Size: 41025 Bits - FPR: 0.000000
#
#
#
# Size: 2113 Bits - FPR: 0.022642
#
#
#
# Size: 4161 Bits - FPR: 0.009434
#
#
#
# Size: 6209 Bits - FPR: 0.000000
#
#
#
# Size: 8257 Bits - FPR: 0.000000
#
#
#
# Size: 10305 Bits - FPR: 0.000000
#
#
#
# Size: 12353 Bits - FPR: 0.000000
#
#
#
# Size: 14401 Bits - FPR: 0.000000
#
#
#
# Size: 16449 Bits - FPR: 0.000000
#
#
#
# Size: 18497 Bits - FPR: 0.000000
#
#
#
# Size: 20545 Bits - FPR: 0.000000
#
#
#
# Size: 22593 Bits - FPR: 0.000000
#
#
#
# Size: 24641 Bits - FPR: 0.000000
#
#
#
# Size: 26689 Bits - FPR: 0.000000
#
#
#
# Size: 28737 Bits - FPR: 0.000000
#
#
#
# Size: 30785 Bits - FPR: 0.000000
#
#
#
# Size: 32833 Bits - FPR: 0.000000
#
#
#
# Size: 34881 Bits - FPR: 0.000000
#
#
#
# Size: 36929 Bits - FPR: 0.000000
#
#
#
# Size: 38977 Bits - FPR: 0.000000
#
#
#
# Size: 41025 Bits - FPR: 0.000000

# %%
n = sum(y_train)
y_ideal_k=[]
for x in size_values_kraska:
    y_ideal_k+=[float(ideal_fpr(x,n))]
print(len(y_ideal_k))
print(n)
# Out:
# 60
# [357]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=fpr_values_kraska, err_style="band",marker="o",label = "Kraska",linestyle= "--",markersize=10)
sns.lineplot(x=size_values_kraska, y=y_ideal_k, err_style="band",marker='>',label = "Ideal",linestyle= ":",markersize = 10)
sns.lineplot(x=size_values_kraska, y=fpr_values_projection, err_style="band",marker='<',label = "Projection",linestyle= "-.",markersize = 10)
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)},style="whitegrid")
sns.lineplot(x=size_values_kraska, y=y_ideal_k, err_style="band",marker='>',label = "Ideal",linestyle= ":",markersize = 10,color="r")
sns.lineplot(x=size_values_kraska, y=fpr_values_projection, err_style="band",marker='<',label = "Projection",linestyle= "-.",markersize = 10,color="g")
plt.title('FPRs')
plt.xlabel("Size", fontsize = 15)
plt.ylabel("FPR", fontsize = 15)
#plt.figure(figsize = (5000,5000))
plt.show()

# %%
plt.plot(size_values_kraska,y_ideal,color='red') #ideal
plt.plot(size_values_kraska,fpr_values,color='green')
plt.plot(size_values_kraska,fpr_values_kraska,color='blue')
